# %% [markdown]
# # NER using NLTK

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
 import nltk
 nltk.download('punkt')
 nltk.download('averaged_perceptron_tagger')
 nltk.download('maxent_ne_chunker')
 nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
DATA_DIR = '/content/drive/MyDrive/Colab Notebooks/TextMining/lab07/sampleText2.txt'
with open(DATA_DIR, 'r',encoding='utf-8', errors='ignore') as f:
     sample = f.read()
#sample = "John drove to a town in Auckland yesterday to buy a Toyota for $5000."
#sample = "John drove town"
sentences = nltk.sent_tokenize(sample)
print("sentences",sentences)
tokenized_sentences = [nltk.word_tokenize(sentence) for sentence in sentences]
print("tokenized_sentences",tokenized_sentences)
tagged_sentences = [nltk.pos_tag(sentence) for sentence in tokenized_sentences]
print("tagged_sentences:",tagged_sentences)
chunked_sentences = nltk.ne_chunk_sents(tagged_sentences, binary=True)
print("chunked_sentences:",chunked_sentences)

def extract_entity_names(t):
    entity_names = []

    if hasattr(t, 'label') and t.label:
        if t.label() == 'NE':
            entity_names.append(' '.join([child[0] for child in t]))
        else:
            for child in t:
                entity_names.extend(extract_entity_names(child))

    return entity_names

entity_names = []
for tree in chunked_sentences:
    #Print results per sentence
    #print(extract_entity_names(tree))
    entity_names.extend(extract_entity_names(tree))



# Print all entity names
print(entity_names)

# Print unique entity names
print (set(entity_names))
print(len(entity_names))
print(len(set(entity_names)))
# Out:
# sentences ['Covid 19 Delta outbreak: Alert level review on way with new vaccine passport - Deputy Prime Minister Grant Robertson.', 'September 27 2021 There are 12 new cases of Covid-19 in the community today.', 'The seven-day rolling average of Covid cases in NZ is now 15, compared with 17 last week and 19 the week before.', 'The Government is reviewing its alert-level system - and broader freedoms - as more Kiwis get vaccinated and with a new vaccine passport on the way.', 'Deputy Prime Minister Grant Robertson said the Government was updating its work around the alert-level framework on the basis it had seen a terrific response to vaccination.', '"We want to push on 90 per cent plus, keep moving and open up a whole range of options for ourselves in the face of Delta," Robertson told The AM Show today.', "In early November there should be a vaccine passport that could be downloaded on people's phones.", 'The app was being managed by the Ministry of Health which was working with private providers to develop it.', 'Work was now under way of what an alert level framework would look like with a vaccine passport and announcements including requirements for it would be likely in the next few weeks.', "Act Party leader David Seymour told Newstalk ZB's Mike Hosking that Level 4 would be gone in its Covid package revealed today.", '"We need to start using isolation in a targeted way.', 'The costs and benefits of isolating a whole city don\'t stack up with Delta."', 'He said isolation should be reserved for people who had recently arrived in New Zealand and there would be an end to MIQ - people could instead do it at home.', 'Robertson said today that public health officials were confident about the situation of the Covid outbreak in Auckland.', 'He acknowledged that a lot of the cases were household contacts.', '"We\'re feeling positive about the direction of travel, but as we\'ve said before, there\'s a long tail with Delta and that\'s what we\'re experiencing now," he told TVNZ\'s Breakfast.', 'Robertson said the Government would not be making vaccinations mandatory.', '"The idea that we would go to a compulsory vaccination goes I think well beyond\nwhere New Zealand has ever been in this regard."', 'New Zealand was doing well enough going without a mandatory vaccination rule.', 'Robertson said the mandatory vaccination rule would be very unpopular among Kiwis and would present human rights issues.', 'The way to get vaccination rates up would include ongoing initiatives already being seen in the community - including the new vaccination buses and Māori and Pasifika-led vaccination hubs - as well as ordinary people helping those in their own families who may still be hesitant about getting the jab.', '"I think this is the bit where every single one of us has a responsibility," he said.', '"Sit down and have that conversation with the person in our lives who\'s maybe a little hesitant ... who is just a bit worried and a bit confused about some info.', '"Each of us gets the chance to be a vaccine hero and go out and have that conversation.', 'That\'s how we\'ll get there," Robertson said.', 'Speaking about vaccine passports, he said that "technology" was being worked on alongside members of the business sector.', 'Bypassing MIQ - the 150 pioneers\nA home-isolation trial for some business travellers has been welcomed as the "first crack" at reopening our borders - but an expert warns it could mean little if the "long tail" of Auckland\'s outbreak is not stamped out.', 'Prime Minister Jacinda Ardern said self-isolation is being considered as a future option in advance of a highly vaccinated public.', 'But, before the country gets to that stage a trial involving 150 fully vaccinated travellers who can bypass MIQ and isolate at home will start at the end of October and run for about six weeks.', "It would be coupled with a testing and monitoring regime and travellers wouldn't be able to leave their homes, or have anyone else there unless  ...
# tokenized_sentences [['Covid', '19', 'Delta', 'outbreak', ':', 'Alert', 'level', 'review', 'on', 'way', 'with', 'new', 'vaccine', 'passport', '-', 'Deputy', 'Prime', 'Minister', 'Grant', 'Robertson', '.'], ['September', '27', '2021', 'There', 'are', '12', 'new', 'cases', 'of', 'Covid-19', 'in', 'the', 'community', 'today', '.'], ['The', 'seven-day', 'rolling', 'average', 'of', 'Covid', 'cases', 'in', 'NZ', 'is', 'now', '15', ',', 'compared', 'with', '17', 'last', 'week', 'and', '19', 'the', 'week', 'before', '.'], ['The', 'Government', 'is', 'reviewing', 'its', 'alert-level', 'system', '-', 'and', 'broader', 'freedoms', '-', 'as', 'more', 'Kiwis', 'get', 'vaccinated', 'and', 'with', 'a', 'new', 'vaccine', 'passport', 'on', 'the', 'way', '.'], ['Deputy', 'Prime', 'Minister', 'Grant', 'Robertson', 'said', 'the', 'Government', 'was', 'updating', 'its', 'work', 'around', 'the', 'alert-level', 'framework', 'on', 'the', 'basis', 'it', 'had', 'seen', 'a', 'terrific', 'response', 'to', 'vaccination', '.'], ['``', 'We', 'want', 'to', 'push', 'on', '90', 'per', 'cent', 'plus', ',', 'keep', 'moving', 'and', 'open', 'up', 'a', 'whole', 'range', 'of', 'options', 'for', 'ourselves', 'in', 'the', 'face', 'of', 'Delta', ',', "''", 'Robertson', 'told', 'The', 'AM', 'Show', 'today', '.'], ['In', 'early', 'November', 'there', 'should', 'be', 'a', 'vaccine', 'passport', 'that', 'could', 'be', 'downloaded', 'on', 'people', "'s", 'phones', '.'], ['The', 'app', 'was', 'being', 'managed', 'by', 'the', 'Ministry', 'of', 'Health', 'which', 'was', 'working', 'with', 'private', 'providers', 'to', 'develop', 'it', '.'], ['Work', 'was', 'now', 'under', 'way', 'of', 'what', 'an', 'alert', 'level', 'framework', 'would', 'look', 'like', 'with', 'a', 'vaccine', 'passport', 'and', 'announcements', 'including', 'requirements', 'for', 'it', 'would', 'be', 'likely', 'in', 'the', 'next', 'few', 'weeks', '.'], ['Act', 'Party', 'leader', 'David', 'Seymour', 'told', 'Newstalk', 'ZB', "'s", 'Mike', 'Hosking', 'that', 'Level', '4', 'would', 'be', 'gone', 'in', 'its', 'Covid', 'package', 'revealed', 'today', '.'], ['``', 'We', 'need', 'to', 'start', 'using', 'isolation', 'in', 'a', 'targeted', 'way', '.'], ['The', 'costs', 'and', 'benefits', 'of', 'isolating', 'a', 'whole', 'city', 'do', "n't", 'stack', 'up', 'with', 'Delta', '.', "''"], ['He', 'said', 'isolation', 'should', 'be', 'reserved', 'for', 'people', 'who', 'had', 'recently', 'arrived', 'in', 'New', 'Zealand', 'and', 'there', 'would', 'be', 'an', 'end', 'to', 'MIQ', '-', 'people', 'could', 'instead', 'do', 'it', 'at', 'home', '.'], ['Robertson', 'said', 'today', 'that', 'public', 'health', 'officials', 'were', 'confident', 'about', 'the', 'situation', 'of', 'the', 'Covid', 'outbreak', 'in', 'Auckland', '.'], ['He', 'acknowledged', 'that', 'a', 'lot', 'of', 'the', 'cases', 'were', 'household', 'contacts', '.'], ['``', 'We', "'re", 'feeling', 'positive', 'about', 'the', 'direction', 'of', 'travel', ',', 'but', 'as', 'we', "'ve", 'said', 'before', ',', 'there', "'s", 'a', 'long', 'tail', 'with', 'Delta', 'and', 'that', "'s", 'what', 'we', "'re", 'experiencing', 'now', ',', "''", 'he', 'told', 'TVNZ', "'s", 'Breakfast', '.'], ['Robertson', 'said', 'the', 'Government', 'would', 'not', 'be', 'making', 'vaccinations', 'mandatory', '.'], ['``', 'The', 'idea', 'that', 'we', 'would', 'go', 'to', 'a', 'compulsory', 'vaccination', 'goes', 'I', 'think', 'well', 'beyond', 'where', 'New', 'Zealand', 'has', 'ever', 'been', 'in', 'this', 'regard', '.', "''"], ['New', 'Zealand', 'was', 'doing', 'well', 'enough', 'going', 'without', 'a', 'mandatory', 'vaccination', 'rule', '.'], ['Robertson', 'said', 'the', 'mandatory', 'vaccination', 'rule', 'would', 'be', 'very', 'unpopular', 'among', 'Kiwis', 'and', 'would', 'present', 'human', 'rights', 'issues', '.'], ['The', 'way', 'to', 'get', 'vaccination', 'rates', 'up', 'would', 'include', 'ongoing', 'initiatives', 'already', 'being', 'seen', 'in', 'the', 'community', '-', 'including', ' ...
# tagged_sentences: [[('Covid', 'NNP'), ('19', 'CD'), ('Delta', 'NNP'), ('outbreak', 'NN'), (':', ':'), ('Alert', 'NNP'), ('level', 'NN'), ('review', 'NN'), ('on', 'IN'), ('way', 'NN'), ('with', 'IN'), ('new', 'JJ'), ('vaccine', 'NN'), ('passport', 'NN'), ('-', ':'), ('Deputy', 'NNP'), ('Prime', 'NNP'), ('Minister', 'NNP'), ('Grant', 'NNP'), ('Robertson', 'NNP'), ('.', '.')], [('September', 'NNP'), ('27', 'CD'), ('2021', 'CD'), ('There', 'EX'), ('are', 'VBP'), ('12', 'CD'), ('new', 'JJ'), ('cases', 'NNS'), ('of', 'IN'), ('Covid-19', 'NNP'), ('in', 'IN'), ('the', 'DT'), ('community', 'NN'), ('today', 'NN'), ('.', '.')], [('The', 'DT'), ('seven-day', 'JJ'), ('rolling', 'JJ'), ('average', 'NN'), ('of', 'IN'), ('Covid', 'NNP'), ('cases', 'NNS'), ('in', 'IN'), ('NZ', 'NNP'), ('is', 'VBZ'), ('now', 'RB'), ('15', 'CD'), (',', ','), ('compared', 'VBN'), ('with', 'IN'), ('17', 'CD'), ('last', 'JJ'), ('week', 'NN'), ('and', 'CC'), ('19', 'CD'), ('the', 'DT'), ('week', 'NN'), ('before', 'IN'), ('.', '.')], [('The', 'DT'), ('Government', 'NNP'), ('is', 'VBZ'), ('reviewing', 'VBG'), ('its', 'PRP$'), ('alert-level', 'NN'), ('system', 'NN'), ('-', ':'), ('and', 'CC'), ('broader', 'JJR'), ('freedoms', 'NNS'), ('-', ':'), ('as', 'IN'), ('more', 'JJR'), ('Kiwis', 'NNP'), ('get', 'VB'), ('vaccinated', 'VBN'), ('and', 'CC'), ('with', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('vaccine', 'NN'), ('passport', 'NN'), ('on', 'IN'), ('the', 'DT'), ('way', 'NN'), ('.', '.')], [('Deputy', 'NNP'), ('Prime', 'NNP'), ('Minister', 'NNP'), ('Grant', 'NNP'), ('Robertson', 'NNP'), ('said', 'VBD'), ('the', 'DT'), ('Government', 'NNP'), ('was', 'VBD'), ('updating', 'VBG'), ('its', 'PRP$'), ('work', 'NN'), ('around', 'IN'), ('the', 'DT'), ('alert-level', 'JJ'), ('framework', 'NN'), ('on', 'IN'), ('the', 'DT'), ('basis', 'NN'), ('it', 'PRP'), ('had', 'VBD'), ('seen', 'VBN'), ('a', 'DT'), ('terrific', 'JJ'), ('response', 'NN'), ('to', 'TO'), ('vaccination', 'NN'), ('.', '.')], [('``', '``'), ('We', 'PRP'), ('want', 'VBP'), ('to', 'TO'), ('push', 'VB'), ('on', 'IN'), ('90', 'CD'), ('per', 'IN'), ('cent', 'NN'), ('plus', 'CC'), (',', ','), ('keep', 'VB'), ('moving', 'NN'), ('and', 'CC'), ('open', 'VB'), ('up', 'RP'), ('a', 'DT'), ('whole', 'JJ'), ('range', 'NN'), ('of', 'IN'), ('options', 'NNS'), ('for', 'IN'), ('ourselves', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('face', 'NN'), ('of', 'IN'), ('Delta', 'NNP'), (',', ','), ("''", "''"), ('Robertson', 'NNP'), ('told', 'VBD'), ('The', 'DT'), ('AM', 'NNP'), ('Show', 'NNP'), ('today', 'NN'), ('.', '.')], [('In', 'IN'), ('early', 'JJ'), ('November', 'NNP'), ('there', 'EX'), ('should', 'MD'), ('be', 'VB'), ('a', 'DT'), ('vaccine', 'NN'), ('passport', 'NN'), ('that', 'WDT'), ('could', 'MD'), ('be', 'VB'), ('downloaded', 'VBN'), ('on', 'IN'), ('people', 'NNS'), ("'s", 'POS'), ('phones', 'NNS'), ('.', '.')], [('The', 'DT'), ('app', 'NN'), ('was', 'VBD'), ('being', 'VBG'), ('managed', 'VBN'), ('by', 'IN'), ('the', 'DT'), ('Ministry', 'NNP'), ('of', 'IN'), ('Health', 'NNP'), ('which', 'WDT'), ('was', 'VBD'), ('working', 'VBG'), ('with', 'IN'), ('private', 'JJ'), ('providers', 'NNS'), ('to', 'TO'), ('develop', 'VB'), ('it', 'PRP'), ('.', '.')], [('Work', 'NN'), ('was', 'VBD'), ('now', 'RB'), ('under', 'IN'), ('way', 'NN'), ('of', 'IN'), ('what', 'WP'), ('an', 'DT'), ('alert', 'JJ'), ('level', 'NN'), ('framework', 'NN'), ('would', 'MD'), ('look', 'VB'), ('like', 'IN'), ('with', 'IN'), ('a', 'DT'), ('vaccine', 'NN'), ('passport', 'NN'), ('and', 'CC'), ('announcements', 'NNS'), ('including', 'VBG'), ('requirements', 'NNS'), ('for', 'IN'), ('it', 'PRP'), ('would', 'MD'), ('be', 'VB'), ('likely', 'RB'), ('in', 'IN'), ('the', 'DT'), ('next', 'JJ'), ('few', 'JJ'), ('weeks', 'NNS'), ('.', '.')], [('Act', 'NNP'), ('Party', 'NNP'), ('leader', 'NN'), ('David', 'NNP'), ('Seymour', 'NNP'), ('told', 'VBD'), ('Newstalk', 'NNP'), ('ZB', 'NNP'), ("'s", 'POS'), ('Mike', 'NNP'), ('Hosking', 'NNP'), ('that', 'IN'), ('Level', 'NNP'), ('4', 'CD'), ('would', 'MD') ...
# chunked_sentences: <generator object ParserI.parse_sents.<locals>.<genexpr> at 0x7e95ea68d5b0>
# ['Alert', 'Grant Robertson', 'Covid', 'NZ', 'Grant Robertson', 'Delta', 'Robertson', 'Ministry', 'Health', 'Work', 'Act Party', 'David Seymour', 'Newstalk ZB', 'Mike Hosking', 'Delta', 'New Zealand', 'MIQ', 'Robertson', 'Covid', 'Auckland', 'Delta', 'TVNZ', 'Robertson', 'New Zealand', 'New Zealand', 'Robertson', 'Kiwis', 'Māori', 'Robertson', 'MIQ', 'Auckland', 'Jacinda Ardern', 'MIQ', 'Ardern', 'Auckland Business', 'Michael Barnett', 'New Zealand', 'MIQ', 'Barnett', 'Auckland', 'New Zealand', 'Covid', 'Epidemiologist Dr Michael Baker', 'Australia', 'Taiwan', 'Hong Kong', 'China', 'New Zealand', 'Pensioner Sue Hotu', 'TVNZ', 'New Zealand', 'Gold Coast', 'MIQ', 'Hotu', 'Hotu', 'MIQ', 'MIQ', 'Hotu', 'Auckland', 'Health Dr Ashley Bloomfield', 'Covid', 'NZ', 'Bloomfield', 'Baker', 'Baker', 'Auckland', 'Act', 'David Seymour', 'Auckland', 'Act', 'RSE', 'Pacific', 'Vanuatu', 'Ardern', 'Vanuatu', 'Samoa', 'Tonga', 'Ardern', 'RSE', 'MIQ']
# {'Health Dr Ashley Bloomfield', 'Act', 'Epidemiologist Dr Michael Baker', 'Michael Barnett', 'Newstalk ZB', 'Pacific', 'Māori', 'Grant Robertson', 'Ardern', 'Work', 'Hotu', 'Australia', 'Robertson', 'Health', 'Covid', 'Gold Coast', 'MIQ', 'Barnett', 'New Zealand', 'Hong Kong', 'Kiwis', 'Ministry', 'Mike Hosking', 'NZ', 'Taiwan', 'Delta', 'Auckland Business', 'Tonga', 'Act Party', 'Jacinda Ardern', 'RSE', 'Vanuatu', 'Alert', 'Samoa', 'Auckland', 'Pensioner Sue Hotu', 'Bloomfield', 'David Seymour', 'Baker', 'TVNZ', 'China'}
# 80
# 41

# %%
for sent in nltk.sent_tokenize(sample):
  for chunk in nltk.ne_chunk(nltk.pos_tag(nltk.word_tokenize(sent))):
     if hasattr(chunk, 'label'):
        print(chunk.label(), ' '.join(c[0] for c in chunk))
# Out:
# PERSON Alert
# PERSON Grant Robertson
# GPE Covid
# GPE NZ
# PERSON Grant Robertson
# GPE Delta
# PERSON Robertson
# ORGANIZATION AM Show
# ORGANIZATION Ministry
# GPE Health
# PERSON Work
# PERSON Act
# ORGANIZATION Party
# PERSON David Seymour
# ORGANIZATION Newstalk
# PERSON Mike Hosking
# PERSON Delta
# GPE New Zealand
# ORGANIZATION MIQ
# PERSON Robertson
# GPE Covid
# GPE Auckland
# PERSON Delta
# ORGANIZATION TVNZ
# PERSON Robertson
# GPE New Zealand
# GPE New
# PERSON Zealand
# PERSON Robertson
# PERSON Kiwis
# PERSON Māori
# PERSON Robertson
# ORGANIZATION MIQ
# GPE Auckland
# PERSON Jacinda Ardern
# ORGANIZATION MIQ
# PERSON Ardern
# ORGANIZATION Auckland Business
# PERSON Michael Barnett
# GPE New Zealand
# ORGANIZATION MIQ
# PERSON Barnett
# GPE Auckland
# ORGANIZATION Delta
# GPE New Zealand
# PERSON Covid
# PERSON Epidemiologist
# PERSON Michael Baker
# GPE Australia
# GPE Taiwan
# GPE Hong Kong
# GPE China
# GPE New Zealand
# PERSON Kiwis
# PERSON Pensioner
# PERSON Sue Hotu
# ORGANIZATION TVNZ
# GPE New Zealand
# ORGANIZATION Gold Coast
# ORGANIZATION MIQ
# PERSON Hotu
# PERSON Hotu
# ORGANIZATION MIQ
# ORGANIZATION MIQ
# PERSON Hotu
# GPE Auckland
# PERSON Health Dr Ashley Bloomfield
# GPE Covid
# PERSON Bloomfield
# PERSON Baker
# PERSON Baker
# GPE Auckland
# GPE Act
# PERSON David Seymour
# GPE Auckland
# ORGANIZATION Business Travel Network
# PERSON Act
# ORGANIZATION RSE
# ORGANIZATION Pacific
# PERSON Vanuatu
# PERSON Ardern
# GPE Vanuatu
# PERSON Samoa
# PERSON Tonga
# PERSON Ardern
# ORGANIZATION MIQ

# %% [markdown]
# #Using Spacy Library

# %%
from os import forkpty
# # Using Spacy NER
import spacy  # Install spacy if required.

nlp = spacy.load('en_core_web_sm')  # Install en_core_web_sm if required.
doc = nlp(sample)

for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
#Grant Robertson 101 116 PERSON
#12 146 148 CARDINAL
#today 188 193 DATE
#seven-day 199 208 DATE


print("######################################################")
file1 = open('/content/drive/MyDrive/Colab Notebooks/TextMining/lab07/deptokens.csv','w')
allTokens = ''
for token in doc:
    tokens = token.text + ',' + token.lemma_+ ',' + token.pos_ + ',' + token.tag_ + ',' + token.dep_ + ',' +\
             token.shape_ + ',' +  str(token.is_alpha) + ',' + str(token.is_stop) + ',' + token.ent_type_ +'\n'
    #print(tokens)
    allTokens = allTokens + tokens
file1.write(allTokens)
file1.close
print(allTokens)

#today,today,NOUN,NN,npadvmod,xxxx,True,False

# filter doc.ents where ent.label_ == 'DATE'

'''
early October 8847 8860 DATE
Ardern 8862 8868 ORG
Vanuatu 8902 8909 GPE
Samoa 8911 8916 ORG
Tonga 8921 8926 GPE
at least one 8938 8950 CARDINAL
Ardern 8965 8971 ORG
RSE 9059 9062 ORG
seven days 9101 9111 DATE
######################################################
Covid,Covid,PROPN,NNP,nmod,Xxxxx,True,False
19,19,NUM,CD,nummod,dd,False,False
Delta,Delta,PROPN,NNP,dobj,Xxxxx,True,False
outbreak,outbreak,NOUN,NN,ROOT,xxxx,True,False
:,:,PUNCT,:,punct,:,False,False
Alert,alert,ADJ,JJ,amod,Xxxxx,True,False
level,level,NOUN,NN,compound,xxxx,True,False
review,review,NOUN,NN,appos,xxxx,True,False
'''
# Out:
# Covid 0 5 PERSON
# 19 6 8 CARDINAL
# Delta 9 14 LOC
# Grant Robertson 101 116 PERSON
# September 27 2021 118 135 DATE
# 12 146 148 CARDINAL
# today 188 193 DATE
# seven-day 199 208 DATE
# Covid 228 233 PERSON
# NZ 243 245 GPE
# 15 253 255 DATE
# 17 last week 271 283 DATE
# 19 the week before 288 306 DATE
# Kiwis 392 397 NORP
# Grant Robertson 479 494 PERSON
# 90 per cent 651 662 MONEY
# Delta 747 752 ORG
# Robertson 755 764 PERSON
# today 782 787 DATE
# early November 792 806 DATE
# the Ministry of Health 916 938 ORG
# the next few weeks 1158 1176 DATE
# Act Party 1178 1187 ORG
# David Seymour 1195 1208 PERSON
# Newstalk ZB's 1214 1227 PERSON
# Mike Hosking 1228 1240 PERSON
# Covid 1275 1280 PERSON
# today 1298 1303 DATE
# Delta 1427 1432 ORG
# New Zealand 1511 1522 GPE
# Robertson 1594 1603 ORG
# today 1609 1614 DATE
# Covid 1686 1691 PERSON
# Auckland 1704 1712 GPE
# Delta 1885 1890 ORG
# TVNZ 1940 1944 ORG
# Breakfast 1947 1956 LOC
# Robertson 1958 1967 ORG
# New Zealand 2118 2129 GPE
# New Zealand 2161 2172 GPE
# Robertson 2239 2248 ORG
# Kiwis 2315 2320 GPE
# Māori 2508 2513 PRODUCT
# Robertson 3027 3036 PERSON
# 150 3185 3188 CARDINAL
# Auckland 3379 3387 PERSON
# Jacinda Ardern 3434 3448 PERSON
# 150 3611 3614 CARDINAL
# MIQ 3658 3661 ORG
# the end of October 3696 3714 DATE
# about six weeks 3727 3742 DATE
# Ardern 3938 3944 ORG
# Auckland Business Chamber 4253 4278 ORG
# Michael Barnett 4283 4298 PERSON
# New Zealand 4336 4347 GPE
# MIQ 4387 4390 ORG
# Barnett 4592 4599 PERSON
# Auckland 4672 4680 ORG
# Delta 4719 4724 LOC
# New Zealand 4897 4908 GPE
# Covid 4950 4955 PERSON
# Michael Baker 5000 5013 PERSON
# tens of thousands 5327 5344 CARDINAL
# Covid-free 5413 5423 PERSON
# Australia 5434 5443 GPE
# Taiwan 5445 5451 GPE
# Hong Kong 5453 5462 GPE
# China 5476 5481 GPE
# New Zealand 5520 5531 GPE
# next year 5539 5548 DATE
# 3000 5839 5843 CARDINAL
# Kiwis 5867 5872 GPE
# 3000 5985 5989 CARDINAL
# Pensioner Sue Hotu 6010 6028 PERSON
# TVNZ 6034 6038 PERSON
# New Zealand 6072 6083 GPE
# the Gold Coast 6089 6103 LOC
# May 6110 6113 DATE
# first 6119 6124 ORDINAL
# Government 6151 6161 ORG
# thousands 6246 6255 CARDINAL
# Hotu 6296 6300 PERSON
# tonight 6328 6335 TIME
# 6pm NZT 6340 6347 TIME
# one 6363 6366 CARDINAL
# 3000 6374 6378 CARDINAL
# about 11,000 6418 6430 CARDINAL
# three hours 6570 6581 TIME
# One 6673 6676 CARDINAL
# Hotu 6683 6687 PERSON
# MIQ 6874 6877 ORG
# 3000 6954 6958 CARDINAL
# 3000 6991 6995 CARDINAL
# today 7097 7102 DATE
# Hotu 7104 7108 PERSON
# Auckland 7180 7188 NORP
# 3 7255 7256 CARDINAL
# the coming days 7274 7289 DATE
# Ashley Bloomfield 7321 7338 PERSON
# seven-day 7348 7357 DATE
# Covid 7377 7382 PERSON
# NZ 7392 7394 GPE
# 15 7403 7405 DATE
# 17 last week 7421 7433 DATE
# 19 the week before 7438 7456 DATE
# Bloomfield 7566 7576 PERSON
# Baker 7583 7588 PERSON
# Baker 7827 7832 PERSON
# Auckland 7839 7847 PERSON
# 2 7880 7881 CARDINAL
# 3 7892 7893 CARDINAL
# David Seymour 7920 7933 PERSON
# the past six months 8032 8051 DATE
# up to thousands 8149 8164 CARDINAL
# Auckland 8239 8247 GPE
# the past seven weeks 8276 8296 DATE
# 150 8309 8312 CARDINAL
# March 8439 8444 DATE
# Covid 8460 8465 PERSON
# 2.0 8466 8469 CARDINAL
# The Business Travel Network 8491 8518 ORG
# Act 8647 8650 PERSON
# RSE 8783 8786 ORG
# Pacific 8804 8811 LOC
# Vanuatu 8834 8841 PERSON
# early October 8847 8860 DATE
# Ardern 8862 8868 ORG
# Vanuatu 8902 8909 GPE
# Samoa 8911 8916 ORG
# Tonga 8921 8926 GPE
# at least one 8938 8950 CARDINAL
# Ardern 8965 8971 ORG
# RSE 9059 9062 ORG
# seven days 9101 9111 DATE
# ######################################################
# Covid,Covid,PROPN,NNP,nmod,Xxxxx,True,False,PERSON
# 19,19,NUM,CD,nummod,dd,False,False,CARDINAL
# Delta,Delta,PROPN,NNP,dobj,Xxxxx,True,False,LOC
# outbreak,outbreak,NOUN,NN,ROOT,xxxx,True,False,
# :,:,PUNCT,:,punct,:,False,False,
# Alert,alert,ADJ,JJ,amod,Xxxxx,True,False,
# level,level,NOUN,NN,compound,xxxx,True,False,
# review,review,NOUN,NN,appos,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# way,way,NOUN,NN,pobj,xxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# new,new,ADJ,JJ,amod,xxx,True,False,
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False,
# passport,passport,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# Deputy,Deputy,PROPN,NNP,compound,Xxxxx,True,False,
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False,
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False,
# Grant,Grant,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Robertson,Robertson,PROPN,NNP,pobj,Xxxxx,True,False,PERSON
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# September,September,PROPN,NNP,npadvmod,Xxxxx,True,False,DATE
# 27,27,NUM,CD,nummod,dd,False,False,DATE
# 2021,2021,NUM,CD,nummod,dddd,False,False,DATE
# There,there,PRON,EX,expl,Xxxxx,True,True,
# are,be,VERB,VBP,ROOT,xxx,True,True,
# 12,12,NUM,CD,nummod,dd,False,False,CARDINAL
# new,new,ADJ,JJ,amod,xxx,True,False,
# cases,case,NOUN,NNS,attr,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# Covid-19,Covid-19,PROPN,NNP,pobj,Xxxxx-dd,False,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# community,community,NOUN,NN,pobj,xxxx,True,False,
# today,today,NOUN,NN,npadvmod,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# seven,seven,NUM,CD,nummod,xxxx,True,False,DATE
# -,-,PUNCT,HYPH,punct,-,False,False,DATE
# day,day,NOUN,NN,compound,xxx,True,False,DATE
# rolling,rolling,NOUN,NN,amod,xxxx,True,False,
# average,average,NOUN,NN,nsubj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False,PERSON
# cases,case,NOUN,NNS,pobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# NZ,NZ,PROPN,NNP,pobj,XX,True,False,GPE
# is,be,AUX,VBZ,ROOT,xx,True,True,
# now,now,ADV,RB,advmod,xxx,True,True,
# 15,15,NUM,CD,attr,dd,False,False,DATE
# ,,,,PUNCT,,,punct,,,False,False,
# compared,compare,VERB,VBN,prep,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# 17,17,NUM,CD,nummod,dd,False,False,DATE
# last,last,ADJ,JJ,amod,xxxx,True,True,DATE
# week,week,NOUN,NN,pobj,xxxx,True,False,DATE
# and,and,CCONJ,CC,cc,xxx,True,True,
# 19,19,NUM,CD,conj,dd,False,False,DATE
# the,the,DET,DT,det,xxx,True,True,DATE
# week,week,NOUN,NN,npadvmod,xxxx,True,False,DATE
# before,before,ADV,RB,advmod,xxxx,True,True,DATE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False,
# is,be,AUX,VBZ,aux,xx,True,True,
# reviewing,review,VERB,VBG,ROOT,xxxx,True,False,
# its,its,PRON,PRP$,poss,xxx,True,True,
# alert,alert,ADJ,JJ,amod,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# level,level,NOUN,NN,compound,xxxx,True,False,
# system,system,NOUN,NN,nmod,xxxx,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# broader,broad,ADJ,JJR,conj,xxxx,True,False,
# freedoms,freedom,NOUN,NNS,dobj,xxxx,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# as,as,SCONJ,IN,mark,xx,True,True,
# more,more,ADJ,JJR,amod,xxxx,True,True,
# Kiwis,Kiwis,PROPN,NNP,nsubjpass,Xxxxx,True,False,NORP
# get,get,AUX,VBP,auxpass,xxx,True,True,
# vaccinated,vaccinate,VERB,VBN,advcl,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# with,with,ADP,IN,prep,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# new,new,ADJ,JJ,amod,xxx,True,False,
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False,
# passport,passport,NOUN,NN,pobj,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# way,way,NOUN,NN,pobj,xxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Deputy,Deputy,PROPN,NNP,compound,Xxxxx,True,False,
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False,
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False,
# Grant,Grant,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False,
# was,be,AUX,VBD,aux,xxx,True,True,
# updating,update,VERB,VBG,ccomp,xxxx,True,False,
# its,its,PRON,PRP$,poss,xxx,True,True,
# work,work,NOUN,NN,dobj,xxxx,True,False,
# around,around,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# alert,alert,ADJ,JJ,amod,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# level,level,NOUN,NN,compound,xxxx,True,False,
# framework,framework,NOUN,NN,pobj,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# basis,basis,NOUN,NN,pobj,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# had,have,AUX,VBD,aux,xxx,True,True,
# seen,see,VERB,VBN,ccomp,xxxx,True,False,
# a,a,DET,DT,det,x,True,True,
# terrific,terrific,ADJ,JJ,amod,xxxx,True,False,
# response,response,NOUN,NN,dobj,xxxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# vaccination,vaccination,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# want,want,VERB,VBP,ccomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# push,push,VERB,VB,xcomp,xxxx,True,False,
# on,on,ADP,RP,prt,xx,True,True,
# 90,90,NUM,CD,nummod,dd,False,False,MONEY
# per,per,ADP,IN,compound,xxx,True,True,MONEY
# cent,cent,NOUN,NN,dobj,xxxx,True,False,MONEY
# plus,plus,CCONJ,CC,advmod,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# keep,keep,VERB,VBP,conj,xxxx,True,True,
# moving,move,VERB,VBG,xcomp,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# open,open,VERB,VB,conj,xxxx,True,False,
# up,up,ADP,RP,prt,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# whole,whole,ADJ,JJ,amod,xxxx,True,True,
# range,range,NOUN,NN,dobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# options,option,NOUN,NNS,pobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# ourselves,ourselves,PRON,PRP,pobj,xxxx,True,True,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# face,face,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False,ORG
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# told,tell,VERB,VBD,ROOT,xxxx,True,False,
# The,the,DET,DT,det,Xxx,True,True,
# AM,AM,PROPN,NNP,compound,XX,True,True,
# Show,Show,PROPN,NNP,dobj,Xxxx,True,True,
# today,today,NOUN,NN,npadvmod,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# In,in,ADP,IN,prep,Xx,True,True,
# early,early,ADJ,JJ,amod,xxxx,True,False,DATE
# November,November,PROPN,NNP,pobj,Xxxxx,True,False,DATE
# there,there,PRON,EX,expl,xxxx,True,True,
# should,should,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,ROOT,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False,
# passport,passport,NOUN,NN,attr,xxxx,True,False,
# that,that,PRON,WDT,nsubjpass,xxxx,True,True,
# could,could,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# downloaded,download,VERB,VBN,relcl,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# people,people,NOUN,NNS,poss,xxxx,True,False,
# 's,'s,PART,POS,case,'x,False,True,
# phones,phone,NOUN,NNS,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# app,app,NOUN,NN,nsubjpass,xxx,True,False,
# was,be,AUX,VBD,aux,xxx,True,True,
# being,be,AUX,VBG,auxpass,xxxx,True,True,
# managed,manage,VERB,VBN,ROOT,xxxx,True,False,
# by,by,ADP,IN,agent,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,ORG
# Ministry,Ministry,PROPN,NNP,pobj,Xxxxx,True,False,ORG
# of,of,ADP,IN,prep,xx,True,True,ORG
# Health,Health,PROPN,NNP,pobj,Xxxxx,True,False,ORG
# which,which,PRON,WDT,nsubj,xxxx,True,True,
# was,be,AUX,VBD,aux,xxx,True,True,
# working,work,VERB,VBG,ccomp,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# private,private,ADJ,JJ,amod,xxxx,True,False,
# providers,provider,NOUN,NNS,pobj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# develop,develop,VERB,VB,advcl,xxxx,True,False,
# it,it,PRON,PRP,dobj,xx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Work,Work,PROPN,NNP,nsubj,Xxxx,True,False,
# was,be,AUX,VBD,ROOT,xxx,True,True,
# now,now,ADV,RB,advmod,xxx,True,True,
# under,under,ADP,IN,prep,xxxx,True,True,
# way,way,NOUN,NN,pobj,xxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# what,what,PRON,WP,pobj,xxxx,True,True,
# an,an,DET,DT,det,xx,True,True,
# alert,alert,ADJ,JJ,amod,xxxx,True,False,
# level,level,NOUN,NN,compound,xxxx,True,False,
# framework,framework,NOUN,NN,nsubj,xxxx,True,False,
# would,would,AUX,MD,aux,xxxx,True,True,
# look,look,VERB,VB,pcomp,xxxx,True,False,
# like,like,ADP,IN,prep,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False,
# passport,passport,NOUN,NN,nsubj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# announcements,announcement,NOUN,NNS,conj,xxxx,True,False,
# including,include,VERB,VBG,prep,xxxx,True,False,
# requirements,requirement,NOUN,NNS,pobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# it,it,PRON,PRP,pobj,xx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,conj,xx,True,True,
# likely,likely,ADJ,JJ,acomp,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,DATE
# next,next,ADJ,JJ,amod,xxxx,True,True,DATE
# few,few,ADJ,JJ,amod,xxx,True,True,DATE
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Act,Act,PROPN,NNP,compound,Xxx,True,False,ORG
# Party,Party,PROPN,NNP,compound,Xxxxx,True,False,ORG
# leader,leader,NOUN,NN,compound,xxxx,True,False,
# David,David,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Seymour,Seymour,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# told,tell,VERB,VBD,ROOT,xxxx,True,False,
# Newstalk,Newstalk,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# ZB,ZB,PROPN,NNP,poss,XX,True,False,PERSON
# 's,'s,PART,POS,case,'x,False,True,PERSON
# Mike,Mike,PROPN,NNP,compound,Xxxx,True,False,PERSON
# Hosking,Hosking,PROPN,NNP,dobj,Xxxxx,True,False,PERSON
# that,that,PRON,DT,mark,xxxx,True,True,
# Level,level,NOUN,NN,nsubjpass,Xxxxx,True,False,
# 4,4,NUM,CD,nummod,d,False,False,
# would,would,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# gone,go,VERB,VBN,ccomp,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# its,its,PRON,PRP$,poss,xxx,True,True,
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False,PERSON
# package,package,NOUN,NN,pobj,xxxx,True,False,
# revealed,reveal,VERB,VBD,ccomp,xxxx,True,False,
# today,today,NOUN,NN,npadvmod,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# need,need,VERB,VBP,ROOT,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# start,start,VERB,VB,xcomp,xxxx,True,False,
# using,use,VERB,VBG,xcomp,xxxx,True,True,
# isolation,isolation,NOUN,NN,dobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# targeted,targeted,ADJ,JJ,amod,xxxx,True,False,
# way,way,NOUN,NN,pobj,xxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# costs,cost,NOUN,NNS,nsubj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# benefits,benefit,NOUN,NNS,conj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# isolating,isolate,VERB,VBG,pcomp,xxxx,True,False,
# a,a,DET,DT,det,x,True,True,
# whole,whole,ADJ,JJ,amod,xxxx,True,True,
# city,city,NOUN,NN,dobj,xxxx,True,False,
# do,do,AUX,VBP,aux,xx,True,True,
# n't,not,PART,RB,neg,x'x,False,True,
# stack,stack,VERB,VB,ROOT,xxxx,True,False,
# up,up,ADP,RP,prt,xx,True,True,
# with,with,ADP,IN,prep,xxxx,True,True,
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False,ORG
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,'',punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# He,he,PRON,PRP,nsubj,Xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# isolation,isolation,NOUN,NN,nsubjpass,xxxx,True,False,
# should,should,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# reserved,reserve,VERB,VBN,ccomp,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# people,people,NOUN,NNS,pobj,xxxx,True,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# had,have,AUX,VBD,aux,xxx,True,True,
# recently,recently,ADV,RB,advmod,xxxx,True,False,
# arrived,arrive,VERB,VBN,relcl,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# New,New,PROPN,NNP,compound,Xxx,True,False,GPE
# Zealand,Zealand,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# and,and,CCONJ,CC,cc,xxx,True,True,
# there,there,PRON,EX,expl,xxxx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,conj,xx,True,True,
# an,an,DET,DT,det,xx,True,True,
# end,end,NOUN,NN,attr,xxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# MIQ,MIQ,PROPN,NNP,compound,XXX,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# people,people,NOUN,NNS,pobj,xxxx,True,False,
# could,could,AUX,MD,aux,xxxx,True,True,
# instead,instead,ADV,RB,advmod,xxxx,True,False,
# do,do,VERB,VB,ccomp,xx,True,True,
# it,it,PRON,PRP,dobj,xx,True,True,
# at,at,ADP,IN,prep,xx,True,True,
# home,home,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# today,today,NOUN,NN,npadvmod,xxxx,True,False,DATE
# that,that,SCONJ,IN,mark,xxxx,True,True,
# public,public,ADJ,JJ,amod,xxxx,True,False,
# health,health,NOUN,NN,compound,xxxx,True,False,
# officials,official,NOUN,NNS,nsubj,xxxx,True,False,
# were,be,AUX,VBD,ccomp,xxxx,True,True,
# confident,confident,ADJ,JJ,acomp,xxxx,True,False,
# about,about,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# situation,situation,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False,PERSON
# outbreak,outbreak,NOUN,NN,pobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# Auckland,Auckland,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# He,he,PRON,PRP,nsubj,Xx,True,True,
# acknowledged,acknowledge,VERB,VBD,ROOT,xxxx,True,False,
# that,that,SCONJ,IN,mark,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# lot,lot,NOUN,NN,nsubj,xxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# cases,case,NOUN,NNS,pobj,xxxx,True,False,
# were,be,AUX,VBD,ccomp,xxxx,True,True,
# household,household,NOUN,NN,compound,xxxx,True,False,
# contacts,contact,NOUN,NNS,attr,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# 're,be,AUX,VBP,aux,'xx,False,True,
# feeling,feel,VERB,VBG,ccomp,xxxx,True,False,
# positive,positive,ADJ,JJ,acomp,xxxx,True,False,
# about,about,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# direction,direction,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# travel,travel,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# but,but,CCONJ,CC,cc,xxx,True,True,
# as,as,SCONJ,IN,mark,xx,True,True,
# we,we,PRON,PRP,nsubj,xx,True,True,
# 've,have,AUX,VBP,aux,'xx,False,True,
# said,say,VERB,VBN,advcl,xxxx,True,False,
# before,before,ADV,RB,advmod,xxxx,True,True,
# ,,,,PUNCT,,,punct,,,False,False,
# there,there,PRON,EX,expl,xxxx,True,True,
# 's,be,VERB,VBZ,conj,'x,False,True,
# a,a,DET,DT,det,x,True,True,
# long,long,ADJ,JJ,amod,xxxx,True,False,
# tail,tail,NOUN,NN,attr,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False,ORG
# and,and,CCONJ,CC,cc,xxx,True,True,
# that,that,PRON,DT,nsubj,xxxx,True,True,
# 's,be,AUX,VBZ,conj,'x,False,True,
# what,what,PRON,WP,dobj,xxxx,True,True,
# we,we,PRON,PRP,nsubj,xx,True,True,
# 're,be,AUX,VBP,aux,'xx,False,True,
# experiencing,experience,VERB,VBG,ccomp,xxxx,True,False,
# now,now,ADV,RB,advmod,xxx,True,True,
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# he,he,PRON,PRP,nsubj,xx,True,True,
# told,tell,VERB,VBD,ROOT,xxxx,True,False,
# TVNZ,TVNZ,PROPN,NNP,poss,XXXX,True,False,ORG
# 's,'s,PART,POS,case,'x,False,True,
# Breakfast,Breakfast,PROPN,NNP,dobj,Xxxxx,True,False,LOC
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False,
# would,would,AUX,MD,aux,xxxx,True,True,
# not,not,PART,RB,neg,xxx,True,True,
# be,be,AUX,VB,aux,xx,True,True,
# making,make,VERB,VBG,ccomp,xxxx,True,False,
# vaccinations,vaccination,NOUN,NNS,nsubj,xxxx,True,False,
# mandatory,mandatory,ADJ,JJ,ccomp,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,``,punct,",False,False,
# The,the,DET,DT,det,Xxx,True,True,
# idea,idea,NOUN,NN,nsubj,xxxx,True,False,
# that,that,SCONJ,IN,mark,xxxx,True,True,
# we,we,PRON,PRP,nsubj,xx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# go,go,VERB,VB,acl,xx,True,True,
# to,to,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# compulsory,compulsory,ADJ,JJ,amod,xxxx,True,False,
# vaccination,vaccination,NOUN,NN,pobj,xxxx,True,False,
# goes,go,VERB,VBZ,ROOT,xxxx,True,False,
# I,I,PRON,PRP,nsubj,X,True,True,
# think,think,VERB,VBP,parataxis,xxxx,True,False,
# well,well,ADV,RB,advmod,xxxx,True,True,
# beyond,beyond,ADP,IN,prep,xxxx,True,True,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# where,where,SCONJ,WRB,advmod,xxxx,True,True,
# New,New,PROPN,NNP,compound,Xxx,True,False,GPE
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False,GPE
# has,have,AUX,VBZ,aux,xxx,True,True,
# ever,ever,ADV,RB,advmod,xxxx,True,True,
# been,be,AUX,VBN,pcomp,xxxx,True,True,
# in,in,ADP,IN,prep,xx,True,True,
# this,this,DET,DT,det,xxxx,True,True,
# regard,regard,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,'',punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# New,New,PROPN,NNP,compound,Xxx,True,False,GPE
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False,GPE
# was,be,AUX,VBD,aux,xxx,True,True,
# doing,do,VERB,VBG,ROOT,xxxx,True,True,
# well,well,ADV,RB,advmod,xxxx,True,True,
# enough,enough,ADV,RB,advmod,xxxx,True,True,
# going,go,VERB,VBG,advcl,xxxx,True,False,
# without,without,ADP,IN,prep,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# mandatory,mandatory,ADJ,JJ,amod,xxxx,True,False,
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False,
# rule,rule,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# mandatory,mandatory,ADJ,JJ,amod,xxxx,True,False,
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False,
# rule,rule,NOUN,NN,nsubj,xxxx,True,False,
# would,would,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,ccomp,xx,True,True,
# very,very,ADV,RB,advmod,xxxx,True,True,
# unpopular,unpopular,ADJ,JJ,acomp,xxxx,True,False,
# among,among,ADP,IN,prep,xxxx,True,True,
# Kiwis,Kiwis,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# and,and,CCONJ,CC,cc,xxx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# present,present,VERB,VB,conj,xxxx,True,False,
# human,human,ADJ,JJ,amod,xxxx,True,False,
# rights,right,NOUN,NNS,compound,xxxx,True,False,
# issues,issue,NOUN,NNS,dobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# way,way,NOUN,NN,nsubj,xxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# get,get,VERB,VB,relcl,xxx,True,True,
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False,
# rates,rate,NOUN,NNS,dobj,xxxx,True,False,
# up,up,ADP,RP,prt,xx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# include,include,VERB,VB,ROOT,xxxx,True,False,
# ongoing,ongoing,ADJ,JJ,amod,xxxx,True,False,
# initiatives,initiative,NOUN,NNS,dobj,xxxx,True,False,
# already,already,ADV,RB,advmod,xxxx,True,True,
# being,be,AUX,VBG,auxpass,xxxx,True,True,
# seen,see,VERB,VBN,acl,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# community,community,NOUN,NN,pobj,xxxx,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# including,include,VERB,VBG,prep,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# new,new,ADJ,JJ,amod,xxx,True,False,
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False,
# buses,bus,NOUN,NNS,pobj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# Māori,Māori,PROPN,NNP,npadvmod,Xxxxx,True,False,PRODUCT
# and,and,CCONJ,CC,cc,xxx,True,True,
# Pasifika,Pasifika,PROPN,NNP,conj,Xxxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# led,lead,VERB,VBN,amod,xxx,True,False,
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False,
# hubs,hub,NOUN,NNS,conj,xxxx,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# as,as,ADV,RB,advmod,xx,True,True,
# well,well,ADV,RB,advmod,xxxx,True,True,
# as,as,ADP,IN,cc,xx,True,True,
# ordinary,ordinary,ADJ,JJ,amod,xxxx,True,False,
# people,people,NOUN,NNS,conj,xxxx,True,False,
# helping,help,VERB,VBG,acl,xxxx,True,False,
# those,those,PRON,DT,dobj,xxxx,True,True,
# in,in,ADP,IN,prep,xx,True,True,
# their,their,PRON,PRP$,poss,xxxx,True,True,
# own,own,ADJ,JJ,amod,xxx,True,True,
# families,family,NOUN,NNS,pobj,xxxx,True,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# may,may,AUX,MD,aux,xxx,True,True,
# still,still,ADV,RB,advmod,xxxx,True,True,
# be,be,AUX,VB,relcl,xx,True,True,
# hesitant,hesitant,ADJ,JJ,acomp,xxxx,True,False,
# about,about,ADP,IN,prep,xxxx,True,True,
# getting,get,VERB,VBG,pcomp,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# jab,jab,NOUN,NN,dobj,xxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# I,I,PRON,PRP,nsubj,X,True,True,
# think,think,VERB,VBP,ccomp,xxxx,True,False,
# this,this,PRON,DT,nsubj,xxxx,True,True,
# is,be,AUX,VBZ,ccomp,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# bit,bit,NOUN,NN,attr,xxx,True,False,
# where,where,SCONJ,WRB,advmod,xxxx,True,True,
# every,every,DET,DT,det,xxxx,True,True,
# single,single,ADJ,JJ,amod,xxxx,True,False,
# one,one,NUM,CD,nsubj,xxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# us,we,PRON,PRP,pobj,xx,True,True,
# has,have,VERB,VBZ,relcl,xxx,True,True,
# a,a,DET,DT,det,x,True,True,
# responsibility,responsibility,NOUN,NN,dobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# he,he,PRON,PRP,nsubj,xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,``,punct,",False,False,
# Sit,sit,VERB,VB,ROOT,Xxx,True,False,
# down,down,ADP,RP,prt,xxxx,True,True,
# and,and,CCONJ,CC,cc,xxx,True,True,
# have,have,VERB,VBP,conj,xxxx,True,True,
# that,that,DET,DT,det,xxxx,True,True,
# conversation,conversation,NOUN,NN,dobj,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# person,person,NOUN,NN,pobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# our,our,PRON,PRP$,poss,xxx,True,True,
# lives,life,NOUN,NNS,pobj,xxxx,True,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# 's,be,AUX,VBZ,ccomp,'x,False,True,
# maybe,maybe,ADV,RB,advmod,xxxx,True,False,
# a,a,DET,DT,det,x,True,True,
# little,little,ADJ,JJ,amod,xxxx,True,False,
# hesitant,hesitant,NOUN,NN,attr,xxxx,True,False,
# ...,...,PUNCT,:,punct,...,False,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# is,be,AUX,VBZ,ccomp,xx,True,True,
# just,just,ADV,RB,advmod,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# bit,bit,NOUN,NN,npadvmod,xxx,True,False,
# worried,worried,ADJ,JJ,acomp,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# a,a,DET,DT,det,x,True,True,
# bit,bit,NOUN,NN,npadvmod,xxx,True,False,
# confused,confused,ADJ,JJ,conj,xxxx,True,False,
# about,about,ADP,IN,prep,xxxx,True,True,
# some,some,DET,DT,det,xxxx,True,True,
# info,info,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# Each,each,PRON,DT,nsubj,Xxxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# us,we,PRON,PRP,pobj,xx,True,True,
# gets,get,VERB,VBZ,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# chance,chance,NOUN,NN,dobj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# be,be,AUX,VB,acl,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False,
# hero,hero,NOUN,NN,attr,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# go,go,VERB,VB,conj,xx,True,True,
# out,out,ADP,RP,advmod,xxx,True,True,
# and,and,CCONJ,CC,cc,xxx,True,True,
# have,have,VERB,VB,conj,xxxx,True,True,
# that,that,DET,DT,det,xxxx,True,True,
# conversation,conversation,NOUN,NN,dobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# That,that,PRON,DT,nsubj,Xxxx,True,True,
# 's,be,AUX,VBZ,ccomp,'x,False,True,
# how,how,SCONJ,WRB,advmod,xxx,True,True,
# we,we,PRON,PRP,nsubj,xx,True,True,
# 'll,will,AUX,MD,aux,'xx,False,True,
# get,get,VERB,VB,ccomp,xxx,True,True,
# there,there,ADV,RB,advmod,xxxx,True,True,
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Speaking,speak,VERB,VBG,csubj,Xxxxx,True,False,
# about,about,ADP,IN,prep,xxxx,True,True,
# vaccine,vaccine,NOUN,NN,pobj,xxxx,True,False,
# passports,passport,VERB,VBZ,advcl,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# he,he,PRON,PRP,nsubj,xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# that,that,SCONJ,IN,mark,xxxx,True,True,
# ",",PUNCT,``,punct,",False,False,
# technology,technology,NOUN,NN,nsubjpass,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# was,be,AUX,VBD,aux,xxx,True,True,
# being,be,AUX,VBG,auxpass,xxxx,True,True,
# worked,work,VERB,VBN,ccomp,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# alongside,alongside,ADP,IN,prep,xxxx,True,False,
# members,member,NOUN,NNS,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# business,business,NOUN,NN,compound,xxxx,True,False,
# sector,sector,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Bypassing,bypass,VERB,VBG,compound,Xxxxx,True,False,
# MIQ,MIQ,PROPN,NNP,dep,XXX,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# the,the,DET,DT,det,xxx,True,True,
# 150,150,NUM,CD,nummod,ddd,False,False,CARDINAL
# pioneers,pioneer,NOUN,NNS,nmod,xxxx,True,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# A,a,DET,DT,det,X,True,True,
# home,home,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,compound,xxxx,True,False,
# trial,trial,NOUN,NN,nsubjpass,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# some,some,DET,DT,det,xxxx,True,True,
# business,business,NOUN,NN,compound,xxxx,True,False,
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False,
# has,have,AUX,VBZ,aux,xxx,True,True,
# been,be,AUX,VBN,auxpass,xxxx,True,True,
# welcomed,welcome,VERB,VBN,ROOT,xxxx,True,False,
# as,as,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# ",",PUNCT,``,punct,",False,False,
# first,first,ADJ,JJ,amod,xxxx,True,True,
# crack,crack,NOUN,NN,pobj,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# at,at,ADP,IN,prep,xx,True,True,
# reopening,reopen,VERB,VBG,pcomp,xxxx,True,False,
# our,our,PRON,PRP$,poss,xxx,True,True,
# borders,border,NOUN,NNS,dobj,xxxx,True,False,
# -,-,PUNCT,:,punct,-,False,False,
# but,but,CCONJ,CC,cc,xxx,True,True,
# an,an,DET,DT,det,xx,True,True,
# expert,expert,NOUN,NN,nsubj,xxxx,True,False,
# warns,warn,VERB,VBZ,conj,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# could,could,AUX,MD,aux,xxxx,True,True,
# mean,mean,VERB,VB,ccomp,xxxx,True,False,
# little,little,ADJ,JJ,amod,xxxx,True,False,
# if,if,SCONJ,IN,mark,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# ",",PUNCT,``,punct,",False,False,
# long,long,ADJ,JJ,amod,xxxx,True,False,
# tail,tail,NOUN,NN,nsubjpass,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# of,of,ADP,IN,prep,xx,True,True,
# Auckland,Auckland,PROPN,NNP,poss,Xxxxx,True,False,PERSON
# 's,'s,PART,POS,case,'x,False,True,
# outbreak,outbreak,NOUN,NN,pobj,xxxx,True,False,
# is,be,AUX,VBZ,auxpass,xx,True,True,
# not,not,PART,RB,neg,xxx,True,True,
# stamped,stamp,VERB,VBN,ccomp,xxxx,True,False,
# out,out,ADP,RP,prt,xxx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False,
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False,
# Jacinda,Jacinda,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,nsubjpass,xxxx,True,False,
# is,be,AUX,VBZ,aux,xx,True,True,
# being,be,AUX,VBG,auxpass,xxxx,True,True,
# considered,consider,VERB,VBN,ccomp,xxxx,True,False,
# as,as,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# future,future,ADJ,JJ,amod,xxxx,True,False,
# option,option,NOUN,NN,pobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# advance,advance,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# highly,highly,ADV,RB,advmod,xxxx,True,False,
# vaccinated,vaccinated,ADJ,JJ,amod,xxxx,True,False,
# public,public,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# But,but,CCONJ,CC,cc,Xxx,True,True,
# ,,,,PUNCT,,,punct,,,False,False,
# before,before,SCONJ,IN,mark,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# country,country,NOUN,NN,nsubj,xxxx,True,False,
# gets,get,VERB,VBZ,advcl,xxxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# that,that,DET,DT,det,xxxx,True,True,
# stage,stage,NOUN,NN,pobj,xxxx,True,False,
# a,a,DET,DT,det,x,True,True,
# trial,trial,NOUN,NN,nsubj,xxxx,True,False,
# involving,involve,VERB,VBG,acl,xxxx,True,False,
# 150,150,NUM,CD,nummod,ddd,False,False,CARDINAL
# fully,fully,ADV,RB,advmod,xxxx,True,False,
# vaccinated,vaccinated,ADJ,JJ,amod,xxxx,True,False,
# travellers,traveller,NOUN,NNS,dobj,xxxx,True,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# can,can,AUX,MD,aux,xxx,True,True,
# bypass,bypass,VERB,VB,relcl,xxxx,True,False,
# MIQ,MIQ,PROPN,NNP,dobj,XXX,True,False,ORG
# and,and,CCONJ,CC,cc,xxx,True,True,
# isolate,isolate,VERB,VB,conj,xxxx,True,False,
# at,at,ADP,IN,prep,xx,True,True,
# home,home,NOUN,NN,pobj,xxxx,True,False,
# will,will,AUX,MD,aux,xxxx,True,True,
# start,start,VERB,VB,ROOT,xxxx,True,False,
# at,at,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,DATE
# end,end,NOUN,NN,pobj,xxx,True,False,DATE
# of,of,ADP,IN,prep,xx,True,True,DATE
# October,October,PROPN,NNP,pobj,Xxxxx,True,False,DATE
# and,and,CCONJ,CC,cc,xxx,True,True,
# run,run,VERB,VB,conj,xxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# about,about,ADV,RB,advmod,xxxx,True,True,DATE
# six,six,NUM,CD,nummod,xxx,True,True,DATE
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# It,it,PRON,PRP,nsubjpass,Xx,True,True,
# would,would,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# coupled,couple,VERB,VBN,ROOT,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# testing,testing,NOUN,NN,nmod,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# monitoring,monitor,VERB,VBG,conj,xxxx,True,False,
# regime,regime,NOUN,NN,pobj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# travellers,traveller,NOUN,NNS,conj,xxxx,True,False,
# would,would,AUX,MD,aux,xxxx,True,True,
# n't,not,PART,RB,neg,x'x,False,True,
# be,be,AUX,VB,conj,xx,True,True,
# able,able,ADJ,JJ,acomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# leave,leave,VERB,VB,xcomp,xxxx,True,False,
# their,their,PRON,PRP$,poss,xxxx,True,True,
# homes,home,NOUN,NNS,dobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# or,or,CCONJ,CC,cc,xx,True,True,
# have,have,VERB,VB,conj,xxxx,True,True,
# anyone,anyone,PRON,NN,dobj,xxxx,True,True,
# else,else,ADV,RB,advmod,xxxx,True,True,
# there,there,ADV,RB,advmod,xxxx,True,True,
# unless,unless,SCONJ,IN,mark,xxxx,True,True,
# they,they,PRON,PRP,nsubj,xxxx,True,True,
# too,too,ADV,RB,advmod,xxx,True,True,
# had,have,AUX,VBD,aux,xxx,True,True,
# travelled,travel,VERB,VBN,advcl,xxxx,True,False,
# as,as,ADP,IN,prep,xx,True,True,
# part,part,NOUN,NN,pobj,xxxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# same,same,ADJ,JJ,amod,xxxx,True,True,
# party,party,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# move,move,NOUN,NN,nsubj,xxxx,True,True,
# was,be,AUX,VBD,ccomp,xxx,True,True,
# an,an,DET,DT,det,xx,True,True,
# indication,indication,NOUN,NN,attr,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# where,where,SCONJ,WRB,advmod,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False,
# wanted,want,VERB,VBD,pcomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# go,go,VERB,VB,xcomp,xx,True,True,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# future,future,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# She,she,PRON,PRP,nsubj,Xxx,True,True,
# was,be,AUX,VBD,aux,xxx,True,True,
# also,also,ADV,RB,advmod,xxxx,True,True,
# looking,look,VERB,VBG,ROOT,xxxx,True,False,
# at,at,ADP,IN,prep,xx,True,True,
# shorter,short,ADJ,JJR,amod,xxxx,True,False,
# periods,period,NOUN,NNS,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# some,some,PRON,DT,pobj,xxxx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# All,all,PRON,DT,nsubj,Xxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# this,this,PRON,DT,pobj,xxxx,True,True,
# will,will,AUX,MD,aux,xxxx,True,True,
# help,help,VERB,VB,ROOT,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# bottlenecks,bottleneck,NOUN,NNS,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# which,which,PRON,WDT,nsubj,xxxx,True,True,
# have,have,AUX,VBP,aux,xxxx,True,True,
# kept,keep,VERB,VBN,relcl,xxxx,True,False,
# our,our,PRON,PRP$,poss,xxx,True,True,
# borders,border,NOUN,NNS,dobj,xxxx,True,False,
# safe,safe,ADJ,JJ,oprd,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,``,punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# Government,Government,PROPN,NNP,poss,Xxxxx,True,False,
# 's,'s,PART,POS,case,'x,False,True,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,compound,xxxx,True,False,
# announcement,announcement,NOUN,NN,nsubjpass,xxxx,True,False,
# has,have,AUX,VBZ,aux,xxx,True,True,
# been,be,AUX,VBN,auxpass,xxxx,True,True,
# welcomed,welcome,VERB,VBN,ROOT,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# open,open,ADJ,JJ,amod,xxxx,True,False,
# arms,arm,NOUN,NNS,pobj,xxxx,True,False,
# by,by,ADP,IN,prep,xx,True,True,
# Auckland,Auckland,PROPN,NNP,compound,Xxxxx,True,False,ORG
# Business,Business,PROPN,NNP,compound,Xxxxx,True,False,ORG
# Chamber,Chamber,PROPN,NNP,compound,Xxxxx,True,False,ORG
# CEO,CEO,PROPN,NNP,compound,XXX,True,False,
# Michael,Michael,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Barnett,Barnett,PROPN,NNP,pobj,Xxxxx,True,False,PERSON
# ,,,,PUNCT,,,punct,,,False,False,
# who,who,PRON,WP,nsubj,xxx,True,True,
# predicted,predict,VERB,VBD,relcl,xxxx,True,False,
# businesses,business,NOUN,NNS,nsubj,xxxx,True,False,
# ",",PUNCT,``,punct,",False,False,
# locked,lock,VERB,VBN,ccomp,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# New,New,PROPN,NNP,compound,Xxx,True,False,GPE
# Zealand,Zealand,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# or,or,CCONJ,CC,cc,xx,True,True,
# marooned,maroon,VERB,VBD,conj,xxxx,True,False,
# overseas,overseas,ADV,RB,advmod,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# locked,lock,VERB,VBN,conj,xxxx,True,False,
# out,out,ADP,IN,prep,xxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# MIQ,MIQ,PROPN,NNP,pobj,XXX,True,False,ORG
# will,will,AUX,MD,aux,xxxx,True,True,
# leap,leap,VERB,VB,conj,xxxx,True,False,
# at,at,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# opportunity,opportunity,NOUN,NN,pobj,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# to,to,PART,TO,aux,xx,True,True,
# participate,participate,VERB,VB,xcomp,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# trial,trial,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# He,he,PRON,PRP,nsubj,Xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# pilot,pilot,NOUN,NN,compound,xxxx,True,False,
# programme,programme,NOUN,NN,nsubj,xxxx,True,False,
# was,be,AUX,VBD,ccomp,xxx,True,True,
# ",",PUNCT,``,punct,",False,False,
# the,the,DET,DT,det,xxx,True,True,
# first,first,ADJ,JJ,amod,xxxx,True,True,
# crack,crack,NOUN,NN,attr,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# open,open,VERB,VB,relcl,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# borders,border,NOUN,NNS,dobj,xxxx,True,False,
# safely,safely,ADV,RB,advmod,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# for,for,ADP,IN,prep,xxx,True,True,
# struggling,struggle,VERB,VBG,pcomp,xxxx,True,False,
# businesses,business,NOUN,NNS,dobj,xxxx,True,False,
# ",",PUNCT,``,punct,",False,False,
# desperate,desperate,ADJ,JJ,oprd,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# get,get,VERB,VB,xcomp,xxx,True,True,
# back,back,ADV,RB,advmod,xxxx,True,True,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# market,market,NOUN,NN,pobj,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Barnett,Barnett,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# predicted,predict,VERB,VBD,ROOT,xxxx,True,False,
# there,there,PRON,EX,expl,xxxx,True,True,
# wo,will,AUX,MD,aux,xx,True,False,
# n't,not,PART,RB,neg,x'x,False,True,
# be,be,AUX,VB,ccomp,xx,True,True,
# any,any,DET,DT,det,xxx,True,True,
# setbacks,setback,NOUN,NNS,attr,xxxx,True,False,
# as,as,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# result,result,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# trial,trial,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# even,even,ADV,RB,advmod,xxxx,True,True,
# as,as,SCONJ,IN,mark,xx,True,True,
# Auckland,Auckland,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# still,still,ADV,RB,advmod,xxxx,True,True,
# battles,battle,VERB,VBZ,advcl,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# eliminate,eliminate,VERB,VB,xcomp,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# latest,late,ADJ,JJS,amod,xxxx,True,False,
# Delta,Delta,PROPN,NNP,compound,Xxxxx,True,False,LOC
# outbreak,outbreak,VERB,VBP,dobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# They,they,PRON,PRP,nsubj,Xxxx,True,True,
# have,have,VERB,VBP,ccomp,xxxx,True,True,
# skin,skin,NOUN,NN,dobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# game,game,NOUN,NN,pobj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# every,every,DET,DT,det,xxxx,True,True,
# business,business,NOUN,NN,conj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# especially,especially,ADV,RB,advmod,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# trailblazers,trailblazer,NOUN,NNS,dobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# this,this,DET,DT,det,xxxx,True,True,
# trial,trial,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# will,will,AUX,MD,aux,xxxx,True,True,
# want,want,VERB,VB,ccomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# show,show,VERB,VB,xcomp,xxxx,True,True,
# that,that,SCONJ,IN,mark,xxxx,True,True,
# they,they,PRON,PRP,nsubj,xxxx,True,True,
# recognise,recognise,VERB,VBP,ccomp,xxxx,True,False,
# that,that,SCONJ,IN,mark,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# ability,ability,NOUN,NN,nsubj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# travel,travel,VERB,VB,acl,xxxx,True,False,
# while,while,SCONJ,IN,mark,xxxx,True,True,
# New,New,PROPN,NNP,compound,Xxx,True,False,GPE
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False,GPE
# is,be,AUX,VBZ,aux,xx,True,True,
# living,live,VERB,VBG,advcl,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# restrictions,restriction,NOUN,NNS,pobj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# eliminate,eliminate,VERB,VB,acl,xxxx,True,False,
# Covid,Covid,PROPN,NNP,dobj,Xxxxx,True,False,PERSON
# is,be,AUX,VBZ,ccomp,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# privilege,privilege,NOUN,NN,attr,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# he,he,PRON,PRP,nsubj,xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Epidemiologist,Epidemiologist,PROPN,NNP,compound,Xxxxx,True,False,
# Dr,Dr,PROPN,NNP,compound,Xx,True,False,
# Michael,Michael,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# was,be,AUX,VBD,ccomp,xxx,True,True,
# good,good,ADJ,JJ,acomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# see,see,VERB,VB,xcomp,xxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,compound,xxxx,True,False,
# trial,trial,NOUN,NN,dobj,xxxx,True,False,
# under,under,ADP,IN,prep,xxxx,True,True,
# way,way,NOUN,NN,pobj,xxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# but,but,CCONJ,CC,cc,xxx,True,True,
# cautioned,caution,VERB,VBD,conj,xxxx,True,False,
# how,how,SCONJ,WRB,advmod,xxx,True,True,
# much,much,ADJ,JJ,nsubjpass,xxxx,True,True,
# could,could,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# learned,learn,VERB,VBN,ccomp,xxxx,True,False,
# from,from,ADP,IN,prep,xxxx,True,True,
# it,it,PRON,PRP,pobj,xx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# To,to,PART,TO,aux,Xx,True,True,
# really,really,ADV,RB,advmod,xxxx,True,True,
# do,do,VERB,VB,ROOT,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# proper,proper,ADJ,JJ,amod,xxxx,True,False,
# study,study,NOUN,NN,dobj,xxxx,True,False,
# you,you,PRON,PRP,nsubj,xxx,True,True,
# need,need,VERB,VBP,relcl,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# do,do,VERB,VB,xcomp,xx,True,True,
# it,it,PRON,PRP,dobj,xx,True,True,
# on,on,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# much,much,ADV,RB,advmod,xxxx,True,True,
# bigger,big,ADJ,JJR,amod,xxxx,True,False,
# scale,scale,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# This,this,PRON,DT,nsubj,Xxxx,True,True,
# will,will,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,ROOT,xx,True,True,
# very,very,ADV,RB,advmod,xxxx,True,True,
# low,low,ADJ,JJ,amod,xxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# risk,risk,NOUN,NN,attr,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# but,but,CCONJ,CC,cc,xxx,True,True,
# it,it,PRON,PRP,nsubj,xx,True,True,
# will,will,AUX,MD,aux,xxxx,True,True,
# show,show,VERB,VB,conj,xxxx,True,True,
# how,how,SCONJ,WRB,advmod,xxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# mechanics,mechanic,NOUN,NNS,nsubj,xxxx,True,False,
# could,could,AUX,MD,aux,xxxx,True,True,
# work,work,VERB,VB,ccomp,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# The,the,DET,DT,det,Xxx,True,True,
# real,real,ADJ,JJ,amod,xxxx,True,False,
# question,question,NOUN,NN,nsubj,xxxx,True,False,
# will,will,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,ROOT,xx,True,True,
# how,how,SCONJ,WRB,advmod,xxx,True,True,
# it,it,PRON,PRP,nsubj,xx,True,True,
# works,work,VERB,VBZ,ccomp,xxxx,True,False,
# when,when,SCONJ,WRB,advmod,xxxx,True,True,
# scaled,scale,VERB,VBN,advcl,xxxx,True,False,
# up,up,ADP,RP,prt,xx,True,True,
# to,to,ADP,IN,prep,xx,True,True,
# tens,ten,NOUN,NNS,quantmod,xxxx,True,False,CARDINAL
# of,of,ADP,IN,quantmod,xx,True,True,CARDINAL
# thousands,thousand,NOUN,NNS,pobj,xxxx,True,False,CARDINAL
# of,of,ADP,IN,prep,xx,True,True,
# people,people,NOUN,NNS,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,'',punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# He,he,PRON,PRP,nsubj,Xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# low,low,ADJ,JJ,amod,xxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# risk,risk,NOUN,NN,compound,xxxx,True,False,
# countries,country,NOUN,NNS,nsubjpass,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# involved,involve,VERB,VBN,ccomp,xxxx,True,False,
# could,could,AUX,MD,aux,xxxx,True,True,
# include,include,VERB,VB,ccomp,xxxx,True,False,
# Covid,Covid,PROPN,NNP,npadvmod,Xxxxx,True,False,PERSON
# -,-,PUNCT,HYPH,punct,-,False,False,PERSON
# free,free,ADJ,JJ,amod,xxxx,True,False,PERSON
# states,state,NOUN,NNS,dobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# Australia,Australia,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# ,,,,PUNCT,,,punct,,,False,False,
# Taiwan,Taiwan,PROPN,NNP,conj,Xxxxx,True,False,GPE
# ,,,,PUNCT,,,punct,,,False,False,
# Hong,Hong,PROPN,NNP,compound,Xxxx,True,False,GPE
# Kong,Kong,PROPN,NNP,conj,Xxxx,True,False,GPE
# and,and,CCONJ,CC,cc,xxx,True,True,
# mainland,mainland,NOUN,NN,compound,xxxx,True,False,
# China,China,PROPN,NNP,conj,Xxxxx,True,False,GPE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# ...
# Dr,Dr,PROPN,NNP,compound,Xx,True,False,
# Ashley,Ashley,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Bloomfield,Bloomfield,PROPN,NNP,pobj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# seven,seven,NUM,CD,nummod,xxxx,True,False,DATE
# -,-,PUNCT,HYPH,punct,-,False,False,DATE
# day,day,NOUN,NN,compound,xxx,True,False,DATE
# rolling,rolling,NOUN,NN,amod,xxxx,True,False,
# average,average,NOUN,NN,nsubj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False,PERSON
# cases,case,NOUN,NNS,pobj,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# NZ,NZ,PROPN,NNP,pobj,XX,True,False,GPE
# was,be,AUX,VBD,ccomp,xxx,True,True,
# now,now,ADV,RB,advmod,xxx,True,True,
# 15,15,NUM,CD,attr,dd,False,False,DATE
# ,,,,PUNCT,,,punct,,,False,False,
# compared,compare,VERB,VBN,prep,xxxx,True,False,
# with,with,ADP,IN,prep,xxxx,True,True,
# 17,17,NUM,CD,nummod,dd,False,False,DATE
# last,last,ADJ,JJ,amod,xxxx,True,True,DATE
# week,week,NOUN,NN,pobj,xxxx,True,False,DATE
# and,and,CCONJ,CC,cc,xxx,True,True,
# 19,19,NUM,CD,conj,dd,False,False,DATE
# the,the,DET,DT,det,xxx,True,True,DATE
# week,week,NOUN,NN,npadvmod,xxxx,True,False,DATE
# before,before,ADV,RB,advmod,xxxx,True,True,DATE
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# are,be,AUX,VBP,aux,xxx,True,True,
# making,make,VERB,VBG,ROOT,xxxx,True,False,
# progress,progress,NOUN,NN,dobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# Many,many,ADJ,JJ,nsubjpass,Xxxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# our,our,PRON,PRP$,poss,xxx,True,True,
# clusters,cluster,NOUN,NNS,pobj,xxxx,True,False,
# are,be,AUX,VBP,auxpass,xxx,True,True,
# now,now,ADV,RB,advmod,xxx,True,True,
# considered,consider,VERB,VBN,ccomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# contained,contain,VERB,VBN,xcomp,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# or,or,CCONJ,CC,cc,xx,True,True,
# clusters,cluster,NOUN,NNS,nsubj,xxxx,True,False,
# are,be,AUX,VBP,conj,xxx,True,True,
# dormant,dormant,ADJ,JJ,acomp,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# ",",PUNCT,'',punct,",False,False,
# Bloomfield,Bloomfield,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# was,be,AUX,VBD,ccomp,xxx,True,True,
# clear,clear,ADJ,JJ,acomp,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# virus,virus,NOUN,NN,nsubj,xxxx,True,False,
# was,be,AUX,VBD,aux,xxx,True,True,
# now,now,ADV,RB,advmod,xxx,True,True,
# continuing,continue,VERB,VBG,ccomp,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# transmit,transmit,VERB,VB,xcomp,xxxx,True,False,
# among,among,ADP,IN,prep,xxxx,True,True,
# specific,specific,ADJ,JJ,amod,xxxx,True,False,
# groups,group,NOUN,NNS,pobj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# there,there,ADV,RB,expl,xxxx,True,True,
# needed,need,VERB,VBD,conj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# be,be,AUX,VB,xcomp,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# much,much,ADV,RB,advmod,xxxx,True,True,
# more,more,ADV,RBR,advmod,xxxx,True,True,
# targeted,targeted,ADJ,JJ,amod,xxxx,True,False,
# approach,approach,NOUN,NN,attr,xxxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# stamping,stamp,VERB,VBG,pcomp,xxxx,True,False,
# out,out,ADP,RP,prt,xxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# virus,virus,NOUN,NN,dobj,xxxx,True,False,
# quickly,quickly,ADV,RB,advmod,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# are,be,AUX,VBP,ROOT,xxx,True,True,
# on,on,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# knife,knife,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# edge,edge,NOUN,NN,pobj,xxxx,True,False,
# at,at,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# moment,moment,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# ",",PUNCT,``,punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Without,without,ADP,IN,prep,Xxxxx,True,True,
# a,a,DET,DT,det,x,True,True,
# targeted,target,VERB,VBN,amod,xxxx,True,False,
# approach,approach,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# said,say,VERB,VBD,parataxis,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# Auckland,Auckland,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# could,could,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,aux,xx,True,True,
# hovering,hover,VERB,VBG,ROOT,xxxx,True,False,
# between,between,ADP,IN,prep,xxxx,True,True,
# level,level,NOUN,NN,pobj,xxxx,True,False,
# 2,2,NUM,CD,nummod,d,False,False,CARDINAL
# and,and,CCONJ,CC,cc,xxx,True,True,
# level,level,NOUN,NN,conj,xxxx,True,False,
# 3,3,NUM,CD,nummod,d,False,False,CARDINAL
# for,for,ADP,IN,prep,xxx,True,True,
# some,some,DET,DT,det,xxxx,True,True,
# time,time,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Act,Act,PROPN,NNP,compound,Xxx,True,False,
# leader,leader,NOUN,NN,compound,xxxx,True,False,
# David,David,PROPN,NNP,compound,Xxxxx,True,False,PERSON
# Seymour,Seymour,PROPN,NNP,nsubj,Xxxxx,True,False,PERSON
# criticised,criticise,VERB,VBD,ROOT,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# length,length,NOUN,NN,dobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# time,time,NOUN,NN,pobj,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# has,have,AUX,VBZ,aux,xxx,True,True,
# taken,take,VERB,VBN,relcl,xxxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# trial,trial,NOUN,NN,compound,xxxx,True,False,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# saying,say,VERB,VBG,advcl,xxxx,True,False,
# nothing,nothing,PRON,NN,nsubj,xxxx,True,True,
# has,have,AUX,VBZ,aux,xxx,True,True,
# changed,change,VERB,VBN,ccomp,xxxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# the,the,DET,DT,det,xxx,True,True,DATE
# past,past,ADJ,JJ,amod,xxxx,True,False,DATE
# six,six,NUM,CD,nummod,xxx,True,True,DATE
# months,month,NOUN,NNS,pobj,xxxx,True,False,DATE
# and,and,CCONJ,CC,cc,xxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# Government,Government,PROPN,NNP,nsubjpass,Xxxxx,True,False,
# was,be,AUX,VBD,aux,xxx,True,True,
# being,be,AUX,VBG,auxpass,xxxx,True,True,
# driven,drive,VERB,VBN,conj,xxxx,True,False,
# by,by,ADP,IN,agent,xx,True,True,
# public,public,ADJ,JJ,amod,xxxx,True,False,
# opinion,opinion,NOUN,NN,compound,xxxx,True,False,
# research,research,NOUN,NN,pobj,xxxx,True,False,
# instead,instead,ADV,RB,advmod,xxxx,True,False,
# of,of,ADP,IN,cc,xx,True,True,
# science,science,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# We,we,PRON,PRP,nsubj,Xx,True,True,
# should,should,AUX,MD,aux,xxxx,True,True,
# be,be,AUX,VB,ROOT,xx,True,True,
# up,up,ADV,RB,advmod,xx,True,True,CARDINAL
# to,to,ADP,IN,prep,xx,True,True,CARDINAL
# thousands,thousand,NOUN,NNS,pobj,xxxx,True,False,CARDINAL
# of,of,ADP,IN,prep,xx,True,True,
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False,
# per,per,ADP,IN,prep,xxx,True,True,
# week,week,NOUN,NN,pobj,xxxx,True,False,
# on,on,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolation,isolation,NOUN,NN,compound,xxxx,True,False,
# scheme,scheme,NOUN,NN,pobj,xxxx,True,False,
# like,like,ADP,IN,prep,xxxx,True,False,
# this,this,PRON,DT,pobj,xxxx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
# The,the,DET,DT,det,Xxx,True,True,
# whole,whole,NOUN,NN,nsubj,xxxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# Auckland,Auckland,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# has,have,AUX,VBZ,aux,xxx,True,True,
# been,be,AUX,VBN,ROOT,xxxx,True,True,
# self,self,NOUN,NN,npadvmod,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolating,isolate,VERB,VBG,acomp,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# the,the,DET,DT,det,xxx,True,True,DATE
# past,past,ADJ,JJ,amod,xxxx,True,False,DATE
# seven,seven,NUM,CD,nummod,xxxx,True,False,DATE
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,DATE
# .,.,PUNCT,.,punct,.,False,False,
# Announcing,announce,VERB,VBG,csubj,Xxxxx,True,False,
# 150,150,NUM,CD,nummod,ddd,False,False,CARDINAL
# travellers,traveller,NOUN,NNS,dobj,xxxx,True,False,
# will,will,AUX,MD,aux,xxxx,True,True,
# self,self,NOUN,NN,compound,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# isolate,isolate,NOUN,NN,nsubj,xxxx,True,False,
# after,after,ADP,IN,prep,xxxx,True,True,
# travelling,travel,VERB,VBG,pcomp,xxxx,True,False,
# is,be,AUX,VBZ,ROOT,xx,True,True,
# hardly,hardly,ADV,RB,advmod,xxxx,True,False,
# news,news,NOUN,NN,acomp,xxxx,True,False,
# to,to,ADP,IN,prep,xx,True,True,
# them,they,PRON,PRP,pobj,xxxx,True,True,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# ",",PUNCT,``,punct,",False,False,
# A,a,DET,DT,det,X,True,True,
# business,business,NOUN,NN,compound,xxxx,True,False,
# travel,travel,NOUN,NN,compound,xxxx,True,False,
# network,network,NOUN,NN,nsubjpass,xxxx,True,False,
# was,be,AUX,VBD,auxpass,xxx,True,True,
# first,first,ADV,RB,advmod,xxxx,True,True,
# proposed,propose,VERB,VBN,ROOT,xxxx,True,False,
# by,by,ADP,IN,agent,xx,True,True,
# Act,Act,PROPN,NNP,pobj,Xxx,True,False,
# in,in,ADP,IN,prep,xx,True,True,
# March,March,PROPN,NNP,pobj,Xxxxx,True,False,DATE
# as,as,ADP,IN,prep,xx,True,True,
# part,part,NOUN,NN,pobj,xxxx,True,True,
# of,of,ADP,IN,prep,xx,True,True,
# our,our,PRON,PRP$,poss,xxx,True,True,
# Covid,Covid,PROPN,NNP,nmod,Xxxxx,True,False,PERSON
# 2.0,2.0,NUM,CD,nummod,d.d,False,False,CARDINAL
# paper,paper,NOUN,NN,pobj,xxxx,True,False,
# when,when,SCONJ,WRB,advmod,xxxx,True,True,
# we,we,PRON,PRP,nsubj,xx,True,True,
# said,say,VERB,VBD,advcl,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# ',',PUNCT,``,punct,',False,False,
# The,the,DET,DT,det,Xxx,True,True,ORG
# Business,Business,PROPN,NNP,compound,Xxxxx,True,False,ORG
# Travel,Travel,PROPN,NNP,compound,Xxxxx,True,False,ORG
# Network,Network,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# would,would,AUX,MD,aux,xxxx,True,True,
# establish,establish,VERB,VB,ccomp,xxxx,True,False,
# special,special,ADJ,JJ,amod,xxxx,True,False,
# requirements,requirement,NOUN,NNS,dobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# business,business,NOUN,NN,compound,xxxx,True,False,
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# come,come,VERB,VB,advcl,xxxx,True,False,
# here,here,ADV,RB,advmod,xxxx,True,True,
# while,while,SCONJ,IN,mark,xxxx,True,True,
# safely,safely,ADV,RB,advmod,xxxx,True,False,
# managing,manage,VERB,VBG,advcl,xxxx,True,False,
# the,the,DET,DT,det,xxx,True,True,
# risk,risk,NOUN,NN,dobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# Covid-19,Covid-19,PROPN,NNP,pobj,Xxxxx-dd,False,False,
# .,.,PUNCT,.,punct,.,False,False,
# ',',PUNCT,'',punct,',False,False,
# ",",PUNCT,``,punct,",False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# He,he,PRON,PRP,nsubj,Xx,True,True,
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# Act,Act,PROPN,NNP,poss,Xxx,True,False,PERSON
# 's,'s,PART,POS,case,'x,False,True,
# policy,policy,NOUN,NN,nsubj,xxxx,True,False,
# also,also,ADV,RB,advmod,xxxx,True,True,
# had,have,VERB,VBD,ccomp,xxx,True,True,
# a,a,DET,DT,det,x,True,True,
# traffic,traffic,NOUN,NN,compound,xxxx,True,False,
# light,light,NOUN,NN,compound,xxxx,True,False,
# system,system,NOUN,NN,dobj,xxxx,True,False,
# and,and,CCONJ,CC,cc,xxx,True,True,
# special,special,ADJ,JJ,amod,xxxx,True,False,
# testing,testing,NOUN,NN,compound,xxxx,True,False,
# requirements,requirement,NOUN,NNS,conj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Meanwhile,meanwhile,ADV,RB,advmod,Xxxxx,True,True,
# ,,,,PUNCT,,,punct,,,False,False,
# the,the,DET,DT,det,xxx,True,True,
# plan,plan,NOUN,NN,nsubj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# reopen,reopen,VERB,VB,acl,xxxx,True,False,
# quarantine,quarantine,NOUN,NN,npadvmod,xxxx,True,False,
# -,-,PUNCT,HYPH,punct,-,False,False,
# free,free,ADJ,JJ,amod,xxxx,True,False,
# travel,travel,NOUN,NN,dobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# RSE,RSE,PROPN,NNP,compound,XXX,True,False,ORG
# workers,worker,NOUN,NNS,pobj,xxxx,True,False,
# from,from,ADP,IN,prep,xxxx,True,True,
# the,the,DET,DT,det,xxx,True,True,
# Pacific,Pacific,PROPN,NNP,pobj,Xxxxx,True,False,LOC
# will,will,AUX,MD,aux,xxxx,True,True,
# start,start,VERB,VB,ccomp,xxxx,True,False,
# again,again,ADV,RB,advmod,xxxx,True,True,
# with,with,ADP,IN,prep,xxxx,True,True,
# Vanuatu,Vanuatu,PROPN,NNP,pobj,Xxxxx,True,False,PERSON
# from,from,ADP,IN,prep,xxxx,True,True,
# early,early,ADJ,JJ,amod,xxxx,True,False,DATE
# October,October,PROPN,NNP,pobj,Xxxxx,True,False,DATE
# ,,,,PUNCT,,,punct,,,False,False,
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# All,all,DET,PDT,predet,Xxx,True,True,
# those,those,PRON,DT,nsubj,xxxx,True,True,
# taking,take,VERB,VBG,acl,xxxx,True,False,
# part,part,NOUN,NN,dobj,xxxx,True,True,
# from,from,ADP,IN,prep,xxxx,True,True,
# Vanuatu,Vanuatu,PROPN,NNP,pobj,Xxxxx,True,False,GPE
# ,,,,PUNCT,,,punct,,,False,False,
# Samoa,Samoa,PROPN,NNP,conj,Xxxxx,True,False,ORG
# and,and,CCONJ,CC,cc,xxx,True,True,
# Tonga,Tonga,PROPN,NNP,conj,Xxxxx,True,False,GPE
# would,would,AUX,MD,aux,xxxx,True,True,
# need,need,VERB,VB,ROOT,xxxx,True,False,
# at,at,ADP,IN,advmod,xx,True,True,CARDINAL
# least,least,ADV,RBS,advmod,xxxx,True,True,CARDINAL
# one,one,NUM,CD,nummod,xxx,True,True,CARDINAL
# vaccine,vaccine,NOUN,NN,nsubj,xxxx,True,False,
# dose,dose,NOUN,NN,ccomp,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False,ORG
# said,say,VERB,VBD,ROOT,xxxx,True,False,
# it,it,PRON,PRP,nsubj,xx,True,True,
# allowed,allow,VERB,VBD,ccomp,xxxx,True,False,
# a,a,DET,DT,det,x,True,True,
# trial,trial,NOUN,NN,dobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# a,a,DET,DT,det,x,True,True,
# ",",PUNCT,``,punct,",False,False,
# pseudo,pseudo,NOUN,NN,nmod,xxxx,True,False,
# ",",PUNCT,'',punct,",False,False,
# form,form,NOUN,NN,pobj,xxxx,True,False,
# of,of,ADP,IN,prep,xx,True,True,
# shortened,shorten,VERB,VBN,amod,xxxx,True,False,
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# some,some,DET,DT,det,xxxx,True,True,
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
#
# ,
# ,SPACE,_SP,dep,
# ,False,False,
# RSE,RSE,PROPN,NNP,compound,XXX,True,False,ORG
# workers,worker,NOUN,NNS,nsubj,xxxx,True,False,
# will,will,AUX,MD,aux,xxxx,True,True,
# also,also,ADV,RB,advmod,xxxx,True,True,
# have,have,VERB,VB,ROOT,xxxx,True,True,
# to,to,PART,TO,aux,xx,True,True,
# isolate,isolate,VERB,VB,xcomp,xxxx,True,False,
# for,for,ADP,IN,prep,xxx,True,True,
# seven,seven,NUM,CD,nummod,xxxx,True,False,DATE
# days,day,NOUN,NNS,pobj,xxxx,True,False,DATE
# on,on,ADP,IN,prep,xx,True,True,
# arrival,arrival,NOUN,NN,pobj,xxxx,True,False,
# ,,,,PUNCT,,,punct,,,False,False,
# but,but,CCONJ,CC,cc,xxx,True,True,
# this,this,PRON,DT,nsubj,xxxx,True,True,
# does,do,AUX,VBZ,aux,xxxx,True,True,
# not,not,PART,RB,neg,xxx,True,True,
# need,need,VERB,VB,conj,xxxx,True,False,
# to,to,PART,TO,aux,xx,True,True,
# be,be,AUX,VB,auxpass,xx,True,True,
# done,do,VERB,VBN,xcomp,xxxx,True,True,
# at,at,ADP,IN,prep,xx,True,True,
# an,an,DET,DT,det,xx,True,True,
# MIQ,MIQ,PROPN,NNP,compound,XXX,True,False,
# facility,facility,NOUN,NN,pobj,xxxx,True,False,
# .,.,PUNCT,.,punct,.,False,False,
# '\nearly October 8847 8860 DATE\nArdern 8862 8868 ORG\nVanuatu 8902 8909 GPE\nSamoa 8911 8916 ORG\nTonga 8921 8926 GPE\nat least one 8938 8950 CARDINAL\nArdern 8965 8971 ORG\nRSE 9059 9062 ORG\nseven days 9101 9111 DATE\n######################################################\nCovid,Covid,PROPN,NNP,nmod,Xxxxx,True,False\n19,19,NUM,CD,nummod,dd,False,False\nDelta,Delta,PROPN,NNP,dobj,Xxxxx,True,False\noutbreak,outbreak,NOUN,NN,ROOT,xxxx,True,False\n:,:,PUNCT,:,punct,:,False,False\nAlert,alert,ADJ,JJ,amod,Xxxxx,True,False\nlevel,level,NOUN,NN,compound,xxxx,True,False\nreview,review,NOUN,NN,appos,xxxx,True,False\n'

# %%
# !python --version
# Out:
# Python 3.10.12

# %%
from datetime import datetime, timedelta
import re

def replace_date(ent):
    lower_name = ent.lower()
    today = datetime.today()
    month_mapping = {
        "january": 1, "february": 2, "march": 3, "april": 4,
        "may": 5, "june": 6, "july": 7, "august": 8,
        "september": 9, "october": 10, "november": 11, "december": 12
    }

    word_to_number = {
    'one': 1,
    'two': 2,
    'three': 3,
    'four': 4,
    'five': 5,
    'six': 6,
    'seven': 7,
    'eight': 8,
    'nine': 9,
    'ten': 10,
    'eleven': 11,
    'twelve': 12,
    'thirteen': 13,
    'fourteen': 14,
    'fifteen': 15,
    'sixteen': 16,
    'seventeen': 17,
    'eighteen': 18,
    'nineteen': 19,
    'twenty': 20,
    'thirty': 30,
    'forty': 40,
    'fifty': 50,
    'sixty': 60,
    'seventy': 70,
    'eighty': 80,
    'ninety': 90,
    'hundred': 100,
    'thousand': 1000,
    'million': 1000000,
    'billion': 1000000000,
}

    if lower_name == 'today':
      t = datetime.now().strftime('%Y-%m-%d')
      return t;

    if lower_name == 'yesterday':
      t = (datetime.now() - timedelta(days=1)).strftime('%Y-%m-%d')
      return t;

    if lower_name == 'next year':
      next_year_start = datetime(today.year + 1, 1, 1)
      next_year_end = datetime(today.year + 1, 12, 31)
      t = f"{next_year_start.strftime('%Y-%m-%d')} TO {next_year_end.strftime('%Y-%m-%d')}"
      return t;


    #  '17 last week','last week'
    if 'last week' in lower_name:
      # Last week (from today to 7 days prior)
      last_week_start = (datetime.now() - timedelta(days=7)).strftime('%Y-%m-%d')
      last_week_end = (datetime.now()).strftime('%Y-%m-%d')
      t = f"{last_week_start} TO {last_week_end}"
      return t;

    # Seven days
    if lower_name == 'seven-day' or lower_name=="seven days":
      #seven_days = "7 DAY"

      # Last seven days (from today to previous seven days)
      last_seven_days_start = (datetime.now() - timedelta(days=7)).strftime('%Y-%m-%d')
      last_seven_days_end = (datetime.now()).strftime('%Y-%m-%d')
      t = f"{last_seven_days_start} TO {last_seven_days_end}"
      return t;

    if lower_name == 'about six weeks':
      # About six weeks (approximate to two dates with 6-week interval)
      six_weeks_start = (datetime.now() - timedelta(weeks=6)).strftime('%Y-%m-%d')
      six_weeks_end = datetime.now().strftime('%Y-%m-%d')
      t = f"{six_weeks_start} TO {six_weeks_end}"
      return t;

    # 'the next few weeks'
    if  lower_name == 'the next few weeks':
        next_few_weeks_start_date = today + timedelta(weeks=1)
        next_few_weeks_end_date = today + timedelta(weeks=3)
        return f"{next_few_weeks_start_date.strftime('%Y-%m-%d')} TO {next_few_weeks_end_date.strftime('%Y-%m-%d')}"

    if lower_name == 'the coming days':
      # coming days (approximate 4-day interval from the current date)
      coming_days_start = datetime.now().strftime('%Y-%m-%d')
      coming_days_end = (datetime.now() + timedelta(days=4)).strftime('%Y-%m-%d')
      t = f"{coming_days_start} TO {coming_days_end}"
      return t;


    #month
    if lower_name in month_mapping:
      c_month = month_mapping[lower_name]
      current_year = datetime.now().year

      start_date = datetime(current_year, c_month, 1)
      next_month = start_date.replace(day=28) + timedelta(days=4)  # Add 4 days to avoid issues with leap years
      end_date = next_month - timedelta(days=next_month.day)

      t = f"{start_date.strftime('%Y-%m-%d')} TO {end_date.strftime('%Y-%m-%d')}"
      return t

    #'September 27 2021'
    pattern = r"^(january|february|march|april|may|june|july|august|september|october|november|december)\s+\d{1,2}\s+\d{4}$"
    if re.match(pattern, lower_name):
      date_obj = datetime.strptime(lower_name, "%B %d %Y")
      t = date_obj.strftime("%Y-%m-%d")
      return t;



    #  '19 the week before'
    pattern = r"^\d{1,2}\s(the week before)$"
    if re.match(pattern, lower_name):
      day = int(lower_name.split()[0])
      two_weeks_ago_date = today - timedelta(weeks=2)
      specific_date = two_weeks_ago_date.replace(day=day)
      t = specific_date.strftime('%Y-%m-%d')
      return t;

    #  'early november'
    pattern = r"^(early)\s(january|february|march|april|may|june|july|august|september|october|november|december)$"
    if re.match(pattern, lower_name):
      c_month = month_mapping[lower_name.split()[1]]
      start_date = datetime(today.year, c_month, 1)
      #next_month = start_date.replace(day=28) + timedelta(days=4)  # Add 4 days to avoid issues with leap years

      end_date = start_date + timedelta(days=4)
      t = f"{start_date.strftime('%Y-%m-%d')} TO {end_date.strftime('%Y-%m-%d')}"
      return t


    #'the past six months', 'the past seven weeks' ，'the end of october'
    pattern = r'the past (\w+) (months|weeks)|the end of (\w+)'
    match = re.search(pattern, lower_name)

    if match:
        if match.group(1) and match.group(2):
            # past week or month
            num_units = word_to_number.get(match.group(1).lower(), match.group(1))
            unit_type = match.group(2)

            print(num_units)
            #print(class(num_nuits))
            print(unit_type)

            if unit_type == 'months':
                start_date = today - timedelta(days=num_units*30)
            elif unit_type == 'weeks':
                start_date = today - timedelta(weeks=num_units)
            end_date = today
        elif match.group(3):
            # the end of month
            month_name = match.group(3)
            c_month = month_mapping[month_name]
            start_date = datetime(today.year, c_month, 1)
            end_date = datetime(today.year, c_month + 1, 1) - timedelta(days=1)

        t = f"{start_date.strftime('%Y-%m-%d')} TO {end_date.strftime('%Y-%m-%d')}"
        return t



    #only day
    pattern = r"^\d{1,2}$"
    if re.match(pattern, lower_name):
      t = f"{today.year:04d}-{today.month:02d}-{int(lower_name):02d}"
      return t;

    # cannot convert,out put original string
    return lower_name



date_entities = [ent.text for ent in doc.ents if ent.label_ == 'DATE']
print("Date entities:", date_entities)


replaced_dates = [replace_date(date) for date in date_entities]
print(replaced_dates)
# Out:
# Date entities: ['September 27 2021', 'today', 'seven-day', '15', '17 last week', '19 the week before', 'today', 'early November', 'the next few weeks', 'today', 'today', 'the end of October', 'about six weeks', 'next year', 'May', 'today', 'the coming days', 'seven-day', '15', '17 last week', '19 the week before', 'the past six months', 'the past seven weeks', 'March', 'early October', 'seven days']
# 6
# months
# 7
# weeks
# ['2021-09-27', '2024-04-09', '2024-04-02 TO 2024-04-09', '2024-04-15', '2024-04-02 TO 2024-04-09', '2024-03-19', '2024-04-09', '2024-11-01 TO 2024-11-05', '2024-04-16 TO 2024-04-30', '2024-04-09', '2024-04-09', '2024-10-01 TO 2024-10-31', '2024-02-27 TO 2024-04-09', '2025-01-01 TO 2025-12-31', '2024-05-01 TO 2024-05-31', '2024-04-09', '2024-04-09 TO 2024-04-13', '2024-04-02 TO 2024-04-09', '2024-04-15', '2024-04-02 TO 2024-04-09', '2024-03-19', '2023-10-12 TO 2024-04-09', '2024-02-20 TO 2024-04-09', '2024-03-01 TO 2024-03-31', '2024-10-01 TO 2024-10-05', '2024-04-02 TO 2024-04-09']

# %%
print("######################################################")
file1 = open('/content/drive/MyDrive/Colab Notebooks/TextMining/lab07/deptokens2.csv','w')
allTokens = ''
for token in doc:
    tokens = token.text + ',' + token.lemma_+ ',' + token.pos_ + ',' + token.tag_ + ',' + token.dep_ + ',' +\
             token.shape_ + ',' +  str(token.is_alpha) + ',' + str(token.is_stop)

    if token.ent_type_ == 'DATE':
      tokens +=  ',' + replace_date(token.text)
    tokens = tokens + '\n'
    #print(tokens)
    allTokens = allTokens + tokens
file1.write(allTokens)
file1.close
print(allTokens)
# Out:
# ######################################################
# Covid,Covid,PROPN,NNP,nmod,Xxxxx,True,False
# 19,19,NUM,CD,nummod,dd,False,False
# Delta,Delta,PROPN,NNP,dobj,Xxxxx,True,False
# outbreak,outbreak,NOUN,NN,ROOT,xxxx,True,False
# :,:,PUNCT,:,punct,:,False,False
# Alert,alert,ADJ,JJ,amod,Xxxxx,True,False
# level,level,NOUN,NN,compound,xxxx,True,False
# review,review,NOUN,NN,appos,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# way,way,NOUN,NN,pobj,xxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# new,new,ADJ,JJ,amod,xxx,True,False
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False
# passport,passport,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# Deputy,Deputy,PROPN,NNP,compound,Xxxxx,True,False
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False
# Grant,Grant,PROPN,NNP,compound,Xxxxx,True,False
# Robertson,Robertson,PROPN,NNP,pobj,Xxxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# September,September,PROPN,NNP,npadvmod,Xxxxx,True,False,2024-09-01 TO 2024-09-30
# 27,27,NUM,CD,nummod,dd,False,False,2024-04-27
# 2021,2021,NUM,CD,nummod,dddd,False,False,2021
# There,there,PRON,EX,expl,Xxxxx,True,True
# are,be,VERB,VBP,ROOT,xxx,True,True
# 12,12,NUM,CD,nummod,dd,False,False
# new,new,ADJ,JJ,amod,xxx,True,False
# cases,case,NOUN,NNS,attr,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Covid-19,Covid-19,PROPN,NNP,pobj,Xxxxx-dd,False,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# community,community,NOUN,NN,pobj,xxxx,True,False
# today,today,NOUN,NN,npadvmod,xxxx,True,False,2024-04-09
# .,.,PUNCT,.,punct,.,False,False
# The,the,DET,DT,det,Xxx,True,True
# seven,seven,NUM,CD,nummod,xxxx,True,False,seven
# -,-,PUNCT,HYPH,punct,-,False,False,-
# day,day,NOUN,NN,compound,xxx,True,False,day
# rolling,rolling,NOUN,NN,amod,xxxx,True,False
# average,average,NOUN,NN,nsubj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False
# cases,case,NOUN,NNS,pobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# NZ,NZ,PROPN,NNP,pobj,XX,True,False
# is,be,AUX,VBZ,ROOT,xx,True,True
# now,now,ADV,RB,advmod,xxx,True,True
# 15,15,NUM,CD,attr,dd,False,False,2024-04-15
# ,,,,PUNCT,,,punct,,,False,False
# compared,compare,VERB,VBN,prep,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# 17,17,NUM,CD,nummod,dd,False,False,2024-04-17
# last,last,ADJ,JJ,amod,xxxx,True,True,last
# week,week,NOUN,NN,pobj,xxxx,True,False,week
# and,and,CCONJ,CC,cc,xxx,True,True
# 19,19,NUM,CD,conj,dd,False,False,2024-04-19
# the,the,DET,DT,det,xxx,True,True,the
# week,week,NOUN,NN,npadvmod,xxxx,True,False,week
# before,before,ADV,RB,advmod,xxxx,True,True,before
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# The,the,DET,DT,det,Xxx,True,True
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False
# is,be,AUX,VBZ,aux,xx,True,True
# reviewing,review,VERB,VBG,ROOT,xxxx,True,False
# its,its,PRON,PRP$,poss,xxx,True,True
# alert,alert,ADJ,JJ,amod,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# level,level,NOUN,NN,compound,xxxx,True,False
# system,system,NOUN,NN,nmod,xxxx,True,False
# -,-,PUNCT,:,punct,-,False,False
# and,and,CCONJ,CC,cc,xxx,True,True
# broader,broad,ADJ,JJR,conj,xxxx,True,False
# freedoms,freedom,NOUN,NNS,dobj,xxxx,True,False
# -,-,PUNCT,:,punct,-,False,False
# as,as,SCONJ,IN,mark,xx,True,True
# more,more,ADJ,JJR,amod,xxxx,True,True
# Kiwis,Kiwis,PROPN,NNP,nsubjpass,Xxxxx,True,False
# get,get,AUX,VBP,auxpass,xxx,True,True
# vaccinated,vaccinate,VERB,VBN,advcl,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# with,with,ADP,IN,prep,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# new,new,ADJ,JJ,amod,xxx,True,False
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False
# passport,passport,NOUN,NN,pobj,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# way,way,NOUN,NN,pobj,xxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Deputy,Deputy,PROPN,NNP,compound,Xxxxx,True,False
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False
# Grant,Grant,PROPN,NNP,compound,Xxxxx,True,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False
# was,be,AUX,VBD,aux,xxx,True,True
# updating,update,VERB,VBG,ccomp,xxxx,True,False
# its,its,PRON,PRP$,poss,xxx,True,True
# work,work,NOUN,NN,dobj,xxxx,True,False
# around,around,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# alert,alert,ADJ,JJ,amod,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# level,level,NOUN,NN,compound,xxxx,True,False
# framework,framework,NOUN,NN,pobj,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# basis,basis,NOUN,NN,pobj,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# had,have,AUX,VBD,aux,xxx,True,True
# seen,see,VERB,VBN,ccomp,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# terrific,terrific,ADJ,JJ,amod,xxxx,True,False
# response,response,NOUN,NN,dobj,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# vaccination,vaccination,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# want,want,VERB,VBP,ccomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# push,push,VERB,VB,xcomp,xxxx,True,False
# on,on,ADP,RP,prt,xx,True,True
# 90,90,NUM,CD,nummod,dd,False,False
# per,per,ADP,IN,compound,xxx,True,True
# cent,cent,NOUN,NN,dobj,xxxx,True,False
# plus,plus,CCONJ,CC,advmod,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# keep,keep,VERB,VBP,conj,xxxx,True,True
# moving,move,VERB,VBG,xcomp,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# open,open,VERB,VB,conj,xxxx,True,False
# up,up,ADP,RP,prt,xx,True,True
# a,a,DET,DT,det,x,True,True
# whole,whole,ADJ,JJ,amod,xxxx,True,True
# range,range,NOUN,NN,dobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# options,option,NOUN,NNS,pobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# ourselves,ourselves,PRON,PRP,pobj,xxxx,True,True
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# face,face,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# told,tell,VERB,VBD,ROOT,xxxx,True,False
# The,the,DET,DT,det,Xxx,True,True
# AM,AM,PROPN,NNP,compound,XX,True,True
# Show,Show,PROPN,NNP,dobj,Xxxx,True,True
# today,today,NOUN,NN,npadvmod,xxxx,True,False,2024-04-09
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# In,in,ADP,IN,prep,Xx,True,True
# early,early,ADJ,JJ,amod,xxxx,True,False,early
# November,November,PROPN,NNP,pobj,Xxxxx,True,False,2024-11-01 TO 2024-11-30
# there,there,PRON,EX,expl,xxxx,True,True
# should,should,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,ROOT,xx,True,True
# a,a,DET,DT,det,x,True,True
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False
# passport,passport,NOUN,NN,attr,xxxx,True,False
# that,that,PRON,WDT,nsubjpass,xxxx,True,True
# could,could,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# downloaded,download,VERB,VBN,relcl,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# people,people,NOUN,NNS,poss,xxxx,True,False
# 's,'s,PART,POS,case,'x,False,True
# phones,phone,NOUN,NNS,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# The,the,DET,DT,det,Xxx,True,True
# app,app,NOUN,NN,nsubjpass,xxx,True,False
# was,be,AUX,VBD,aux,xxx,True,True
# being,be,AUX,VBG,auxpass,xxxx,True,True
# managed,manage,VERB,VBN,ROOT,xxxx,True,False
# by,by,ADP,IN,agent,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# Ministry,Ministry,PROPN,NNP,pobj,Xxxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Health,Health,PROPN,NNP,pobj,Xxxxx,True,False
# which,which,PRON,WDT,nsubj,xxxx,True,True
# was,be,AUX,VBD,aux,xxx,True,True
# working,work,VERB,VBG,ccomp,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# private,private,ADJ,JJ,amod,xxxx,True,False
# providers,provider,NOUN,NNS,pobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# develop,develop,VERB,VB,advcl,xxxx,True,False
# it,it,PRON,PRP,dobj,xx,True,True
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Work,Work,PROPN,NNP,nsubj,Xxxx,True,False
# was,be,AUX,VBD,ROOT,xxx,True,True
# now,now,ADV,RB,advmod,xxx,True,True
# under,under,ADP,IN,prep,xxxx,True,True
# way,way,NOUN,NN,pobj,xxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# what,what,PRON,WP,pobj,xxxx,True,True
# an,an,DET,DT,det,xx,True,True
# alert,alert,ADJ,JJ,amod,xxxx,True,False
# level,level,NOUN,NN,compound,xxxx,True,False
# framework,framework,NOUN,NN,nsubj,xxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# look,look,VERB,VB,pcomp,xxxx,True,False
# like,like,ADP,IN,prep,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False
# passport,passport,NOUN,NN,nsubj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# announcements,announcement,NOUN,NNS,conj,xxxx,True,False
# including,include,VERB,VBG,prep,xxxx,True,False
# requirements,requirement,NOUN,NNS,pobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# it,it,PRON,PRP,pobj,xx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,conj,xx,True,True
# likely,likely,ADJ,JJ,acomp,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True,the
# next,next,ADJ,JJ,amod,xxxx,True,True,next
# few,few,ADJ,JJ,amod,xxx,True,True,few
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,weeks
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Act,Act,PROPN,NNP,compound,Xxx,True,False
# Party,Party,PROPN,NNP,compound,Xxxxx,True,False
# leader,leader,NOUN,NN,compound,xxxx,True,False
# David,David,PROPN,NNP,compound,Xxxxx,True,False
# Seymour,Seymour,PROPN,NNP,nsubj,Xxxxx,True,False
# told,tell,VERB,VBD,ROOT,xxxx,True,False
# Newstalk,Newstalk,PROPN,NNP,compound,Xxxxx,True,False
# ZB,ZB,PROPN,NNP,poss,XX,True,False
# 's,'s,PART,POS,case,'x,False,True
# Mike,Mike,PROPN,NNP,compound,Xxxx,True,False
# Hosking,Hosking,PROPN,NNP,dobj,Xxxxx,True,False
# that,that,PRON,DT,mark,xxxx,True,True
# Level,level,NOUN,NN,nsubjpass,Xxxxx,True,False
# 4,4,NUM,CD,nummod,d,False,False
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# gone,go,VERB,VBN,ccomp,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# its,its,PRON,PRP$,poss,xxx,True,True
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False
# package,package,NOUN,NN,pobj,xxxx,True,False
# revealed,reveal,VERB,VBD,ccomp,xxxx,True,False
# today,today,NOUN,NN,npadvmod,xxxx,True,False,2024-04-09
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# need,need,VERB,VBP,ROOT,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# start,start,VERB,VB,xcomp,xxxx,True,False
# using,use,VERB,VBG,xcomp,xxxx,True,True
# isolation,isolation,NOUN,NN,dobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# targeted,targeted,ADJ,JJ,amod,xxxx,True,False
# way,way,NOUN,NN,pobj,xxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# The,the,DET,DT,det,Xxx,True,True
# costs,cost,NOUN,NNS,nsubj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# benefits,benefit,NOUN,NNS,conj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# isolating,isolate,VERB,VBG,pcomp,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# whole,whole,ADJ,JJ,amod,xxxx,True,True
# city,city,NOUN,NN,dobj,xxxx,True,False
# do,do,AUX,VBP,aux,xx,True,True
# n't,not,PART,RB,neg,x'x,False,True
# stack,stack,VERB,VB,ROOT,xxxx,True,False
# up,up,ADP,RP,prt,xx,True,True
# with,with,ADP,IN,prep,xxxx,True,True
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,'',punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# He,he,PRON,PRP,nsubj,Xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# isolation,isolation,NOUN,NN,nsubjpass,xxxx,True,False
# should,should,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# reserved,reserve,VERB,VBN,ccomp,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# people,people,NOUN,NNS,pobj,xxxx,True,False
# who,who,PRON,WP,nsubj,xxx,True,True
# had,have,AUX,VBD,aux,xxx,True,True
# recently,recently,ADV,RB,advmod,xxxx,True,False
# arrived,arrive,VERB,VBN,relcl,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,pobj,Xxxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# there,there,PRON,EX,expl,xxxx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,conj,xx,True,True
# an,an,DET,DT,det,xx,True,True
# end,end,NOUN,NN,attr,xxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# MIQ,MIQ,PROPN,NNP,compound,XXX,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# people,people,NOUN,NNS,pobj,xxxx,True,False
# could,could,AUX,MD,aux,xxxx,True,True
# instead,instead,ADV,RB,advmod,xxxx,True,False
# do,do,VERB,VB,ccomp,xx,True,True
# it,it,PRON,PRP,dobj,xx,True,True
# at,at,ADP,IN,prep,xx,True,True
# home,home,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# today,today,NOUN,NN,npadvmod,xxxx,True,False,2024-04-09
# that,that,SCONJ,IN,mark,xxxx,True,True
# public,public,ADJ,JJ,amod,xxxx,True,False
# health,health,NOUN,NN,compound,xxxx,True,False
# officials,official,NOUN,NNS,nsubj,xxxx,True,False
# were,be,AUX,VBD,ccomp,xxxx,True,True
# confident,confident,ADJ,JJ,acomp,xxxx,True,False
# about,about,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# situation,situation,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False
# outbreak,outbreak,NOUN,NN,pobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# Auckland,Auckland,PROPN,NNP,pobj,Xxxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# He,he,PRON,PRP,nsubj,Xx,True,True
# acknowledged,acknowledge,VERB,VBD,ROOT,xxxx,True,False
# that,that,SCONJ,IN,mark,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# lot,lot,NOUN,NN,nsubj,xxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# cases,case,NOUN,NNS,pobj,xxxx,True,False
# were,be,AUX,VBD,ccomp,xxxx,True,True
# household,household,NOUN,NN,compound,xxxx,True,False
# contacts,contact,NOUN,NNS,attr,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# 're,be,AUX,VBP,aux,'xx,False,True
# feeling,feel,VERB,VBG,ccomp,xxxx,True,False
# positive,positive,ADJ,JJ,acomp,xxxx,True,False
# about,about,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# direction,direction,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# travel,travel,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# but,but,CCONJ,CC,cc,xxx,True,True
# as,as,SCONJ,IN,mark,xx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# 've,have,AUX,VBP,aux,'xx,False,True
# said,say,VERB,VBN,advcl,xxxx,True,False
# before,before,ADV,RB,advmod,xxxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# there,there,PRON,EX,expl,xxxx,True,True
# 's,be,VERB,VBZ,conj,'x,False,True
# a,a,DET,DT,det,x,True,True
# long,long,ADJ,JJ,amod,xxxx,True,False
# tail,tail,NOUN,NN,attr,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# Delta,Delta,PROPN,NNP,pobj,Xxxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# that,that,PRON,DT,nsubj,xxxx,True,True
# 's,be,AUX,VBZ,conj,'x,False,True
# what,what,PRON,WP,dobj,xxxx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# 're,be,AUX,VBP,aux,'xx,False,True
# experiencing,experience,VERB,VBG,ccomp,xxxx,True,False
# now,now,ADV,RB,advmod,xxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# he,he,PRON,PRP,nsubj,xx,True,True
# told,tell,VERB,VBD,ROOT,xxxx,True,False
# TVNZ,TVNZ,PROPN,NNP,poss,XXXX,True,False
# 's,'s,PART,POS,case,'x,False,True
# Breakfast,Breakfast,PROPN,NNP,dobj,Xxxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# not,not,PART,RB,neg,xxx,True,True
# be,be,AUX,VB,aux,xx,True,True
# making,make,VERB,VBG,ccomp,xxxx,True,False
# vaccinations,vaccination,NOUN,NNS,nsubj,xxxx,True,False
# mandatory,mandatory,ADJ,JJ,ccomp,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
# The,the,DET,DT,det,Xxx,True,True
# idea,idea,NOUN,NN,nsubj,xxxx,True,False
# that,that,SCONJ,IN,mark,xxxx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# go,go,VERB,VB,acl,xx,True,True
# to,to,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# compulsory,compulsory,ADJ,JJ,amod,xxxx,True,False
# vaccination,vaccination,NOUN,NN,pobj,xxxx,True,False
# goes,go,VERB,VBZ,ROOT,xxxx,True,False
# I,I,PRON,PRP,nsubj,X,True,True
# think,think,VERB,VBP,parataxis,xxxx,True,False
# well,well,ADV,RB,advmod,xxxx,True,True
# beyond,beyond,ADP,IN,prep,xxxx,True,True
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# where,where,SCONJ,WRB,advmod,xxxx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False
# has,have,AUX,VBZ,aux,xxx,True,True
# ever,ever,ADV,RB,advmod,xxxx,True,True
# been,be,AUX,VBN,pcomp,xxxx,True,True
# in,in,ADP,IN,prep,xx,True,True
# this,this,DET,DT,det,xxxx,True,True
# regard,regard,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,'',punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False
# was,be,AUX,VBD,aux,xxx,True,True
# doing,do,VERB,VBG,ROOT,xxxx,True,True
# well,well,ADV,RB,advmod,xxxx,True,True
# enough,enough,ADV,RB,advmod,xxxx,True,True
# going,go,VERB,VBG,advcl,xxxx,True,False
# without,without,ADP,IN,prep,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# mandatory,mandatory,ADJ,JJ,amod,xxxx,True,False
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# rule,rule,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# mandatory,mandatory,ADJ,JJ,amod,xxxx,True,False
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# rule,rule,NOUN,NN,nsubj,xxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,ccomp,xx,True,True
# very,very,ADV,RB,advmod,xxxx,True,True
# unpopular,unpopular,ADJ,JJ,acomp,xxxx,True,False
# among,among,ADP,IN,prep,xxxx,True,True
# Kiwis,Kiwis,PROPN,NNP,pobj,Xxxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# present,present,VERB,VB,conj,xxxx,True,False
# human,human,ADJ,JJ,amod,xxxx,True,False
# rights,right,NOUN,NNS,compound,xxxx,True,False
# issues,issue,NOUN,NNS,dobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# The,the,DET,DT,det,Xxx,True,True
# way,way,NOUN,NN,nsubj,xxx,True,False
# to,to,PART,TO,aux,xx,True,True
# get,get,VERB,VB,relcl,xxx,True,True
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# rates,rate,NOUN,NNS,dobj,xxxx,True,False
# up,up,ADP,RP,prt,xx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# include,include,VERB,VB,ROOT,xxxx,True,False
# ongoing,ongoing,ADJ,JJ,amod,xxxx,True,False
# initiatives,initiative,NOUN,NNS,dobj,xxxx,True,False
# already,already,ADV,RB,advmod,xxxx,True,True
# being,be,AUX,VBG,auxpass,xxxx,True,True
# seen,see,VERB,VBN,acl,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# community,community,NOUN,NN,pobj,xxxx,True,False
# -,-,PUNCT,:,punct,-,False,False
# including,include,VERB,VBG,prep,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# new,new,ADJ,JJ,amod,xxx,True,False
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# buses,bus,NOUN,NNS,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# Māori,Māori,PROPN,NNP,npadvmod,Xxxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# Pasifika,Pasifika,PROPN,NNP,conj,Xxxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# led,lead,VERB,VBN,amod,xxx,True,False
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# hubs,hub,NOUN,NNS,conj,xxxx,True,False
# -,-,PUNCT,:,punct,-,False,False
# as,as,ADV,RB,advmod,xx,True,True
# well,well,ADV,RB,advmod,xxxx,True,True
# as,as,ADP,IN,cc,xx,True,True
# ordinary,ordinary,ADJ,JJ,amod,xxxx,True,False
# people,people,NOUN,NNS,conj,xxxx,True,False
# helping,help,VERB,VBG,acl,xxxx,True,False
# those,those,PRON,DT,dobj,xxxx,True,True
# in,in,ADP,IN,prep,xx,True,True
# their,their,PRON,PRP$,poss,xxxx,True,True
# own,own,ADJ,JJ,amod,xxx,True,True
# families,family,NOUN,NNS,pobj,xxxx,True,False
# who,who,PRON,WP,nsubj,xxx,True,True
# may,may,AUX,MD,aux,xxx,True,True
# still,still,ADV,RB,advmod,xxxx,True,True
# be,be,AUX,VB,relcl,xx,True,True
# hesitant,hesitant,ADJ,JJ,acomp,xxxx,True,False
# about,about,ADP,IN,prep,xxxx,True,True
# getting,get,VERB,VBG,pcomp,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# jab,jab,NOUN,NN,dobj,xxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# I,I,PRON,PRP,nsubj,X,True,True
# think,think,VERB,VBP,ccomp,xxxx,True,False
# this,this,PRON,DT,nsubj,xxxx,True,True
# is,be,AUX,VBZ,ccomp,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# bit,bit,NOUN,NN,attr,xxx,True,False
# where,where,SCONJ,WRB,advmod,xxxx,True,True
# every,every,DET,DT,det,xxxx,True,True
# single,single,ADJ,JJ,amod,xxxx,True,False
# one,one,NUM,CD,nsubj,xxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# us,we,PRON,PRP,pobj,xx,True,True
# has,have,VERB,VBZ,relcl,xxx,True,True
# a,a,DET,DT,det,x,True,True
# responsibility,responsibility,NOUN,NN,dobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# he,he,PRON,PRP,nsubj,xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
# Sit,sit,VERB,VB,ROOT,Xxx,True,False
# down,down,ADP,RP,prt,xxxx,True,True
# and,and,CCONJ,CC,cc,xxx,True,True
# have,have,VERB,VBP,conj,xxxx,True,True
# that,that,DET,DT,det,xxxx,True,True
# conversation,conversation,NOUN,NN,dobj,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# person,person,NOUN,NN,pobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# our,our,PRON,PRP$,poss,xxx,True,True
# lives,life,NOUN,NNS,pobj,xxxx,True,False
# who,who,PRON,WP,nsubj,xxx,True,True
# 's,be,AUX,VBZ,ccomp,'x,False,True
# maybe,maybe,ADV,RB,advmod,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# little,little,ADJ,JJ,amod,xxxx,True,False
# hesitant,hesitant,NOUN,NN,attr,xxxx,True,False
# ...,...,PUNCT,:,punct,...,False,False
# who,who,PRON,WP,nsubj,xxx,True,True
# is,be,AUX,VBZ,ccomp,xx,True,True
# just,just,ADV,RB,advmod,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# bit,bit,NOUN,NN,npadvmod,xxx,True,False
# worried,worried,ADJ,JJ,acomp,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# a,a,DET,DT,det,x,True,True
# bit,bit,NOUN,NN,npadvmod,xxx,True,False
# confused,confused,ADJ,JJ,conj,xxxx,True,False
# about,about,ADP,IN,prep,xxxx,True,True
# some,some,DET,DT,det,xxxx,True,True
# info,info,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# Each,each,PRON,DT,nsubj,Xxxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# us,we,PRON,PRP,pobj,xx,True,True
# gets,get,VERB,VBZ,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# chance,chance,NOUN,NN,dobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# be,be,AUX,VB,acl,xx,True,True
# a,a,DET,DT,det,x,True,True
# vaccine,vaccine,NOUN,NN,compound,xxxx,True,False
# hero,hero,NOUN,NN,attr,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# go,go,VERB,VB,conj,xx,True,True
# out,out,ADP,RP,advmod,xxx,True,True
# and,and,CCONJ,CC,cc,xxx,True,True
# have,have,VERB,VB,conj,xxxx,True,True
# that,that,DET,DT,det,xxxx,True,True
# conversation,conversation,NOUN,NN,dobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# That,that,PRON,DT,nsubj,Xxxx,True,True
# 's,be,AUX,VBZ,ccomp,'x,False,True
# how,how,SCONJ,WRB,advmod,xxx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# 'll,will,AUX,MD,aux,'xx,False,True
# get,get,VERB,VB,ccomp,xxx,True,True
# there,there,ADV,RB,advmod,xxxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# Robertson,Robertson,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Speaking,speak,VERB,VBG,csubj,Xxxxx,True,False
# about,about,ADP,IN,prep,xxxx,True,True
# vaccine,vaccine,NOUN,NN,pobj,xxxx,True,False
# passports,passport,VERB,VBZ,advcl,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# he,he,PRON,PRP,nsubj,xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# that,that,SCONJ,IN,mark,xxxx,True,True
# ",",PUNCT,``,punct,",False,False
# technology,technology,NOUN,NN,nsubjpass,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# was,be,AUX,VBD,aux,xxx,True,True
# being,be,AUX,VBG,auxpass,xxxx,True,True
# worked,work,VERB,VBN,ccomp,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# alongside,alongside,ADP,IN,prep,xxxx,True,False
# members,member,NOUN,NNS,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# business,business,NOUN,NN,compound,xxxx,True,False
# sector,sector,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Bypassing,bypass,VERB,VBG,compound,Xxxxx,True,False
# MIQ,MIQ,PROPN,NNP,dep,XXX,True,False
# -,-,PUNCT,:,punct,-,False,False
# the,the,DET,DT,det,xxx,True,True
# 150,150,NUM,CD,nummod,ddd,False,False
# pioneers,pioneer,NOUN,NNS,nmod,xxxx,True,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# A,a,DET,DT,det,X,True,True
# home,home,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,compound,xxxx,True,False
# trial,trial,NOUN,NN,nsubjpass,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# some,some,DET,DT,det,xxxx,True,True
# business,business,NOUN,NN,compound,xxxx,True,False
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False
# has,have,AUX,VBZ,aux,xxx,True,True
# been,be,AUX,VBN,auxpass,xxxx,True,True
# welcomed,welcome,VERB,VBN,ROOT,xxxx,True,False
# as,as,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# ",",PUNCT,``,punct,",False,False
# first,first,ADJ,JJ,amod,xxxx,True,True
# crack,crack,NOUN,NN,pobj,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# at,at,ADP,IN,prep,xx,True,True
# reopening,reopen,VERB,VBG,pcomp,xxxx,True,False
# our,our,PRON,PRP$,poss,xxx,True,True
# borders,border,NOUN,NNS,dobj,xxxx,True,False
# -,-,PUNCT,:,punct,-,False,False
# but,but,CCONJ,CC,cc,xxx,True,True
# an,an,DET,DT,det,xx,True,True
# expert,expert,NOUN,NN,nsubj,xxxx,True,False
# warns,warn,VERB,VBZ,conj,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# could,could,AUX,MD,aux,xxxx,True,True
# mean,mean,VERB,VB,ccomp,xxxx,True,False
# little,little,ADJ,JJ,amod,xxxx,True,False
# if,if,SCONJ,IN,mark,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# ",",PUNCT,``,punct,",False,False
# long,long,ADJ,JJ,amod,xxxx,True,False
# tail,tail,NOUN,NN,nsubjpass,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# of,of,ADP,IN,prep,xx,True,True
# Auckland,Auckland,PROPN,NNP,poss,Xxxxx,True,False
# 's,'s,PART,POS,case,'x,False,True
# outbreak,outbreak,NOUN,NN,pobj,xxxx,True,False
# is,be,AUX,VBZ,auxpass,xx,True,True
# not,not,PART,RB,neg,xxx,True,True
# stamped,stamp,VERB,VBN,ccomp,xxxx,True,False
# out,out,ADP,RP,prt,xxx,True,True
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Prime,Prime,PROPN,NNP,compound,Xxxxx,True,False
# Minister,Minister,PROPN,NNP,compound,Xxxxx,True,False
# Jacinda,Jacinda,PROPN,NNP,compound,Xxxxx,True,False
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,nsubjpass,xxxx,True,False
# is,be,AUX,VBZ,aux,xx,True,True
# being,be,AUX,VBG,auxpass,xxxx,True,True
# considered,consider,VERB,VBN,ccomp,xxxx,True,False
# as,as,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# future,future,ADJ,JJ,amod,xxxx,True,False
# option,option,NOUN,NN,pobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# advance,advance,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# highly,highly,ADV,RB,advmod,xxxx,True,False
# vaccinated,vaccinated,ADJ,JJ,amod,xxxx,True,False
# public,public,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# But,but,CCONJ,CC,cc,Xxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# before,before,SCONJ,IN,mark,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# country,country,NOUN,NN,nsubj,xxxx,True,False
# gets,get,VERB,VBZ,advcl,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# that,that,DET,DT,det,xxxx,True,True
# stage,stage,NOUN,NN,pobj,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# trial,trial,NOUN,NN,nsubj,xxxx,True,False
# involving,involve,VERB,VBG,acl,xxxx,True,False
# 150,150,NUM,CD,nummod,ddd,False,False
# fully,fully,ADV,RB,advmod,xxxx,True,False
# vaccinated,vaccinated,ADJ,JJ,amod,xxxx,True,False
# travellers,traveller,NOUN,NNS,dobj,xxxx,True,False
# who,who,PRON,WP,nsubj,xxx,True,True
# can,can,AUX,MD,aux,xxx,True,True
# bypass,bypass,VERB,VB,relcl,xxxx,True,False
# MIQ,MIQ,PROPN,NNP,dobj,XXX,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# isolate,isolate,VERB,VB,conj,xxxx,True,False
# at,at,ADP,IN,prep,xx,True,True
# home,home,NOUN,NN,pobj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# start,start,VERB,VB,ROOT,xxxx,True,False
# at,at,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True,the
# end,end,NOUN,NN,pobj,xxx,True,False,end
# of,of,ADP,IN,prep,xx,True,True,of
# October,October,PROPN,NNP,pobj,Xxxxx,True,False,2024-10-01 TO 2024-10-31
# and,and,CCONJ,CC,cc,xxx,True,True
# run,run,VERB,VB,conj,xxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# about,about,ADV,RB,advmod,xxxx,True,True,about
# six,six,NUM,CD,nummod,xxx,True,True,six
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,weeks
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# It,it,PRON,PRP,nsubjpass,Xx,True,True
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# coupled,couple,VERB,VBN,ROOT,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# a,a,DET,DT,det,x,True,True
# testing,testing,NOUN,NN,nmod,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# monitoring,monitor,VERB,VBG,conj,xxxx,True,False
# regime,regime,NOUN,NN,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# travellers,traveller,NOUN,NNS,conj,xxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# n't,not,PART,RB,neg,x'x,False,True
# be,be,AUX,VB,conj,xx,True,True
# able,able,ADJ,JJ,acomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# leave,leave,VERB,VB,xcomp,xxxx,True,False
# their,their,PRON,PRP$,poss,xxxx,True,True
# homes,home,NOUN,NNS,dobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# or,or,CCONJ,CC,cc,xx,True,True
# have,have,VERB,VB,conj,xxxx,True,True
# anyone,anyone,PRON,NN,dobj,xxxx,True,True
# else,else,ADV,RB,advmod,xxxx,True,True
# there,there,ADV,RB,advmod,xxxx,True,True
# unless,unless,SCONJ,IN,mark,xxxx,True,True
# they,they,PRON,PRP,nsubj,xxxx,True,True
# too,too,ADV,RB,advmod,xxx,True,True
# had,have,AUX,VBD,aux,xxx,True,True
# travelled,travel,VERB,VBN,advcl,xxxx,True,False
# as,as,ADP,IN,prep,xx,True,True
# part,part,NOUN,NN,pobj,xxxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# same,same,ADJ,JJ,amod,xxxx,True,True
# party,party,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# move,move,NOUN,NN,nsubj,xxxx,True,True
# was,be,AUX,VBD,ccomp,xxx,True,True
# an,an,DET,DT,det,xx,True,True
# indication,indication,NOUN,NN,attr,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# where,where,SCONJ,WRB,advmod,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# Government,Government,PROPN,NNP,nsubj,Xxxxx,True,False
# wanted,want,VERB,VBD,pcomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# go,go,VERB,VB,xcomp,xx,True,True
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# future,future,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# She,she,PRON,PRP,nsubj,Xxx,True,True
# was,be,AUX,VBD,aux,xxx,True,True
# also,also,ADV,RB,advmod,xxxx,True,True
# looking,look,VERB,VBG,ROOT,xxxx,True,False
# at,at,ADP,IN,prep,xx,True,True
# shorter,short,ADJ,JJR,amod,xxxx,True,False
# periods,period,NOUN,NNS,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# some,some,PRON,DT,pobj,xxxx,True,True
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# All,all,PRON,DT,nsubj,Xxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# this,this,PRON,DT,pobj,xxxx,True,True
# will,will,AUX,MD,aux,xxxx,True,True
# help,help,VERB,VB,ROOT,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# bottlenecks,bottleneck,NOUN,NNS,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# which,which,PRON,WDT,nsubj,xxxx,True,True
# have,have,AUX,VBP,aux,xxxx,True,True
# kept,keep,VERB,VBN,relcl,xxxx,True,False
# our,our,PRON,PRP$,poss,xxx,True,True
# borders,border,NOUN,NNS,dobj,xxxx,True,False
# safe,safe,ADJ,JJ,oprd,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# The,the,DET,DT,det,Xxx,True,True
# Government,Government,PROPN,NNP,poss,Xxxxx,True,False
# 's,'s,PART,POS,case,'x,False,True
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,compound,xxxx,True,False
# announcement,announcement,NOUN,NN,nsubjpass,xxxx,True,False
# has,have,AUX,VBZ,aux,xxx,True,True
# been,be,AUX,VBN,auxpass,xxxx,True,True
# welcomed,welcome,VERB,VBN,ROOT,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# open,open,ADJ,JJ,amod,xxxx,True,False
# arms,arm,NOUN,NNS,pobj,xxxx,True,False
# by,by,ADP,IN,prep,xx,True,True
# Auckland,Auckland,PROPN,NNP,compound,Xxxxx,True,False
# Business,Business,PROPN,NNP,compound,Xxxxx,True,False
# Chamber,Chamber,PROPN,NNP,compound,Xxxxx,True,False
# CEO,CEO,PROPN,NNP,compound,XXX,True,False
# Michael,Michael,PROPN,NNP,compound,Xxxxx,True,False
# Barnett,Barnett,PROPN,NNP,pobj,Xxxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# who,who,PRON,WP,nsubj,xxx,True,True
# predicted,predict,VERB,VBD,relcl,xxxx,True,False
# businesses,business,NOUN,NNS,nsubj,xxxx,True,False
# ",",PUNCT,``,punct,",False,False
# locked,lock,VERB,VBN,ccomp,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,pobj,Xxxxx,True,False
# or,or,CCONJ,CC,cc,xx,True,True
# marooned,maroon,VERB,VBD,conj,xxxx,True,False
# overseas,overseas,ADV,RB,advmod,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# locked,lock,VERB,VBN,conj,xxxx,True,False
# out,out,ADP,IN,prep,xxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# MIQ,MIQ,PROPN,NNP,pobj,XXX,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# leap,leap,VERB,VB,conj,xxxx,True,False
# at,at,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# opportunity,opportunity,NOUN,NN,pobj,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# to,to,PART,TO,aux,xx,True,True
# participate,participate,VERB,VB,xcomp,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# trial,trial,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# He,he,PRON,PRP,nsubj,Xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# pilot,pilot,NOUN,NN,compound,xxxx,True,False
# programme,programme,NOUN,NN,nsubj,xxxx,True,False
# was,be,AUX,VBD,ccomp,xxx,True,True
# ",",PUNCT,``,punct,",False,False
# the,the,DET,DT,det,xxx,True,True
# first,first,ADJ,JJ,amod,xxxx,True,True
# crack,crack,NOUN,NN,attr,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# open,open,VERB,VB,relcl,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# borders,border,NOUN,NNS,dobj,xxxx,True,False
# safely,safely,ADV,RB,advmod,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# for,for,ADP,IN,prep,xxx,True,True
# struggling,struggle,VERB,VBG,pcomp,xxxx,True,False
# businesses,business,NOUN,NNS,dobj,xxxx,True,False
# ",",PUNCT,``,punct,",False,False
# desperate,desperate,ADJ,JJ,oprd,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# get,get,VERB,VB,xcomp,xxx,True,True
# back,back,ADV,RB,advmod,xxxx,True,True
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# market,market,NOUN,NN,pobj,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Barnett,Barnett,PROPN,NNP,nsubj,Xxxxx,True,False
# predicted,predict,VERB,VBD,ROOT,xxxx,True,False
# there,there,PRON,EX,expl,xxxx,True,True
# wo,will,AUX,MD,aux,xx,True,False
# n't,not,PART,RB,neg,x'x,False,True
# be,be,AUX,VB,ccomp,xx,True,True
# any,any,DET,DT,det,xxx,True,True
# setbacks,setback,NOUN,NNS,attr,xxxx,True,False
# as,as,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# result,result,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# trial,trial,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# even,even,ADV,RB,advmod,xxxx,True,True
# as,as,SCONJ,IN,mark,xx,True,True
# Auckland,Auckland,PROPN,NNP,nsubj,Xxxxx,True,False
# still,still,ADV,RB,advmod,xxxx,True,True
# battles,battle,VERB,VBZ,advcl,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# eliminate,eliminate,VERB,VB,xcomp,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# latest,late,ADJ,JJS,amod,xxxx,True,False
# Delta,Delta,PROPN,NNP,compound,Xxxxx,True,False
# outbreak,outbreak,VERB,VBP,dobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# They,they,PRON,PRP,nsubj,Xxxx,True,True
# have,have,VERB,VBP,ccomp,xxxx,True,True
# skin,skin,NOUN,NN,dobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# game,game,NOUN,NN,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# every,every,DET,DT,det,xxxx,True,True
# business,business,NOUN,NN,conj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# especially,especially,ADV,RB,advmod,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# trailblazers,trailblazer,NOUN,NNS,dobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# this,this,DET,DT,det,xxxx,True,True
# trial,trial,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# will,will,AUX,MD,aux,xxxx,True,True
# want,want,VERB,VB,ccomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# show,show,VERB,VB,xcomp,xxxx,True,True
# that,that,SCONJ,IN,mark,xxxx,True,True
# they,they,PRON,PRP,nsubj,xxxx,True,True
# recognise,recognise,VERB,VBP,ccomp,xxxx,True,False
# that,that,SCONJ,IN,mark,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# ability,ability,NOUN,NN,nsubj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# travel,travel,VERB,VB,acl,xxxx,True,False
# while,while,SCONJ,IN,mark,xxxx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False
# is,be,AUX,VBZ,aux,xx,True,True
# living,live,VERB,VBG,advcl,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# restrictions,restriction,NOUN,NNS,pobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# eliminate,eliminate,VERB,VB,acl,xxxx,True,False
# Covid,Covid,PROPN,NNP,dobj,Xxxxx,True,False
# is,be,AUX,VBZ,ccomp,xx,True,True
# a,a,DET,DT,det,x,True,True
# privilege,privilege,NOUN,NN,attr,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# he,he,PRON,PRP,nsubj,xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Epidemiologist,Epidemiologist,PROPN,NNP,compound,Xxxxx,True,False
# Dr,Dr,PROPN,NNP,compound,Xx,True,False
# Michael,Michael,PROPN,NNP,compound,Xxxxx,True,False
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# was,be,AUX,VBD,ccomp,xxx,True,True
# good,good,ADJ,JJ,acomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# see,see,VERB,VB,xcomp,xxx,True,True
# the,the,DET,DT,det,xxx,True,True
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,compound,xxxx,True,False
# trial,trial,NOUN,NN,dobj,xxxx,True,False
# under,under,ADP,IN,prep,xxxx,True,True
# way,way,NOUN,NN,pobj,xxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# but,but,CCONJ,CC,cc,xxx,True,True
# cautioned,caution,VERB,VBD,conj,xxxx,True,False
# how,how,SCONJ,WRB,advmod,xxx,True,True
# much,much,ADJ,JJ,nsubjpass,xxxx,True,True
# could,could,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# learned,learn,VERB,VBN,ccomp,xxxx,True,False
# from,from,ADP,IN,prep,xxxx,True,True
# it,it,PRON,PRP,pobj,xx,True,True
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# To,to,PART,TO,aux,Xx,True,True
# really,really,ADV,RB,advmod,xxxx,True,True
# do,do,VERB,VB,ROOT,xx,True,True
# a,a,DET,DT,det,x,True,True
# proper,proper,ADJ,JJ,amod,xxxx,True,False
# study,study,NOUN,NN,dobj,xxxx,True,False
# you,you,PRON,PRP,nsubj,xxx,True,True
# need,need,VERB,VBP,relcl,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# do,do,VERB,VB,xcomp,xx,True,True
# it,it,PRON,PRP,dobj,xx,True,True
# on,on,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# much,much,ADV,RB,advmod,xxxx,True,True
# bigger,big,ADJ,JJR,amod,xxxx,True,False
# scale,scale,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# This,this,PRON,DT,nsubj,Xxxx,True,True
# will,will,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,ROOT,xx,True,True
# very,very,ADV,RB,advmod,xxxx,True,True
# low,low,ADJ,JJ,amod,xxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# risk,risk,NOUN,NN,attr,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# but,but,CCONJ,CC,cc,xxx,True,True
# it,it,PRON,PRP,nsubj,xx,True,True
# will,will,AUX,MD,aux,xxxx,True,True
# show,show,VERB,VB,conj,xxxx,True,True
# how,how,SCONJ,WRB,advmod,xxx,True,True
# the,the,DET,DT,det,xxx,True,True
# mechanics,mechanic,NOUN,NNS,nsubj,xxxx,True,False
# could,could,AUX,MD,aux,xxxx,True,True
# work,work,VERB,VB,ccomp,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# The,the,DET,DT,det,Xxx,True,True
# real,real,ADJ,JJ,amod,xxxx,True,False
# question,question,NOUN,NN,nsubj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,ROOT,xx,True,True
# how,how,SCONJ,WRB,advmod,xxx,True,True
# it,it,PRON,PRP,nsubj,xx,True,True
# works,work,VERB,VBZ,ccomp,xxxx,True,False
# when,when,SCONJ,WRB,advmod,xxxx,True,True
# scaled,scale,VERB,VBN,advcl,xxxx,True,False
# up,up,ADP,RP,prt,xx,True,True
# to,to,ADP,IN,prep,xx,True,True
# tens,ten,NOUN,NNS,quantmod,xxxx,True,False
# of,of,ADP,IN,quantmod,xx,True,True
# thousands,thousand,NOUN,NNS,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# people,people,NOUN,NNS,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,'',punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# He,he,PRON,PRP,nsubj,Xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# low,low,ADJ,JJ,amod,xxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# risk,risk,NOUN,NN,compound,xxxx,True,False
# countries,country,NOUN,NNS,nsubjpass,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# involved,involve,VERB,VBN,ccomp,xxxx,True,False
# could,could,AUX,MD,aux,xxxx,True,True
# include,include,VERB,VB,ccomp,xxxx,True,False
# Covid,Covid,PROPN,NNP,npadvmod,Xxxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# free,free,ADJ,JJ,amod,xxxx,True,False
# states,state,NOUN,NNS,dobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# Australia,Australia,PROPN,NNP,pobj,Xxxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# Taiwan,Taiwan,PROPN,NNP,conj,Xxxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# Hong,Hong,PROPN,NNP,compound,Xxxx,True,False
# Kong,Kong,PROPN,NNP,conj,Xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# mainland,mainland,NOUN,NN,compound,xxxx,True,False
# China,China,PROPN,NNP,conj,Xxxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# The,the,DET,DT,det,Xxx,True,True
# bigger,big,ADJ,JJR,amod,xxxx,True,False
# question,question,NOUN,NN,nsubj,xxxx,True,False
# though,though,ADV,RB,mark,xxxx,True,True
# was,be,AUX,VBD,ccomp,xxx,True,True
# where,where,SCONJ,WRB,advmod,xxxx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,nsubj,Xxxxx,True,False
# was,be,AUX,VBD,advcl,xxx,True,True
# at,at,ADP,IN,prep,xx,True,True
# next,next,ADJ,JJ,amod,xxxx,True,True,next
# year,year,NOUN,NN,pobj,xxxx,True,False,year
# with,with,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# virus,virus,NOUN,NN,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# if,if,SCONJ,IN,mark,xx,True,True
# it,it,PRON,PRP,nsubj,xx,True,True
# was,be,AUX,VBD,aux,xxx,True,True
# still,still,ADV,RB,advmod,xxxx,True,True
# circulating,circulate,VERB,VBG,conj,xxxx,True,False
# here,here,ADV,RB,advmod,xxxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# along,along,ADP,IN,prep,xxxx,True,True
# with,with,ADP,IN,prep,xxxx,True,True
# vaccination,vaccination,NOUN,NN,compound,xxxx,True,False
# levels,level,NOUN,NNS,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# he,he,PRON,PRP,nsubj,xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# If,if,SCONJ,IN,mark,Xx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# are,be,AUX,VBP,advcl,xxx,True,True
# still,still,ADV,RB,advmod,xxxx,True,True
# in,in,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# situation,situation,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# little,little,ADJ,JJ,amod,xxxx,True,False
# or,or,CCONJ,CC,cc,xx,True,True
# no,no,PRON,DT,conj,xx,True,True
# transmission,transmission,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# so,so,ADV,RB,advmod,xx,True,True
# still,still,ADV,RB,advmod,xxxx,True,True
# elimination,elimination,NOUN,NN,ROOT,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# compared,compare,VERB,VBN,prep,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# endemic,endemic,ADJ,JJ,amod,xxxx,True,False
# spread,spread,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# virus,virus,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# Those,those,DET,DT,det,Xxxxx,True,True
# things,thing,NOUN,NNS,nsubj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# determine,determine,VERB,VB,ROOT,xxxx,True,False
# our,our,PRON,PRP$,poss,xxx,True,True
# tolerance,tolerance,NOUN,NN,dobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# the,the,DET,DT,det,xxx,True,True
# virus,virus,NOUN,NN,nsubj,xxxx,True,False
# coming,come,VERB,VBG,pcomp,xxxx,True,False
# in,in,ADV,RB,prt,xx,True,True
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# 3000,3000,NUM,CD,nummod,dddd,False,False
# MIQ,MIQ,PROPN,NNP,nsubj,XXX,True,False
# rooms,room,NOUN,NNS,nsubj,xxxx,True,False
# up,up,ADP,RP,prt,xx,True,True
# for,for,ADP,IN,prep,xxx,True,True
# grabs,grab,NOUN,NNS,compound,xxxx,True,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Kiwis,Kiwis,PROPN,NNP,pobj,Xxxxx,True,False
# overseas,overseas,ADV,RB,advmod,xxxx,True,False
# hoping,hope,VERB,VBG,advcl,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# get,get,VERB,VB,xcomp,xxx,True,True
# home,home,NOUN,NN,dobj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# have,have,VERB,VB,ROOT,xxxx,True,True
# another,another,DET,DT,det,xxxx,True,True
# chance,chance,NOUN,NN,dobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# secure,secure,VERB,VB,acl,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# spot,spot,NOUN,NN,dobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# managed,manage,VERB,VBN,amod,xxxx,True,False
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# quarantine,quarantine,NOUN,NN,conj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# when,when,SCONJ,WRB,advmod,xxxx,True,True
# 3000,3000,NUM,CD,nummod,dddd,False,False
# rooms,room,NOUN,NNS,nsubj,xxxx,True,False
# go,go,VERB,VBP,relcl,xx,True,True
# up,up,ADV,RB,advmod,xx,True,True
# online,online,ADV,RB,advmod,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Pensioner,Pensioner,PROPN,NNP,compound,Xxxxx,True,False
# Sue,Sue,PROPN,NNP,compound,Xxx,True,False
# Hotu,Hotu,PROPN,NNP,nsubj,Xxxx,True,False
# told,tell,VERB,VBD,ROOT,xxxx,True,False
# TVNZ,TVNZ,PROPN,NNP,dobj,XXXX,True,False
# she,she,PRON,PRP,nsubj,xxx,True,True
# had,have,AUX,VBD,aux,xxx,True,True
# been,be,AUX,VBN,aux,xxxx,True,True
# trying,try,VERB,VBG,ccomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# return,return,VERB,VB,xcomp,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# New,New,PROPN,NNP,compound,Xxx,True,False
# Zealand,Zealand,PROPN,NNP,pobj,Xxxxx,True,False
# from,from,ADP,IN,prep,xxxx,True,True
# ...
# Auckland,Auckland,PROPN,NNP,compound,Xxxxx,True,False
# outbreak,outbreak,NOUN,NN,nsubj,xxxx,True,False
# was,be,AUX,VBD,advcl,xxx,True,True
# under,under,ADP,IN,prep,xxxx,True,True
# control,control,NOUN,NN,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# any,any,DET,DT,det,xxx,True,True
# effects,effect,NOUN,NNS,nsubjpass,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# change,change,NOUN,NN,pobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# level,level,VERB,VB,relcl,xxxx,True,False
# 3,3,NUM,CD,dobj,d,False,False
# would,would,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# seen,see,VERB,VBN,conj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True,the
# coming,come,VERB,VBG,amod,xxxx,True,False,coming
# days,day,NOUN,NNS,pobj,xxxx,True,False,days
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Director,Director,PROPN,NNP,compound,Xxxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# general,general,NOUN,NN,nsubj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Health,Health,PROPN,NNP,compound,Xxxxx,True,False
# Dr,Dr,PROPN,NNP,compound,Xx,True,False
# Ashley,Ashley,PROPN,NNP,compound,Xxxxx,True,False
# Bloomfield,Bloomfield,PROPN,NNP,pobj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# seven,seven,NUM,CD,nummod,xxxx,True,False,seven
# -,-,PUNCT,HYPH,punct,-,False,False,-
# day,day,NOUN,NN,compound,xxx,True,False,day
# rolling,rolling,NOUN,NN,amod,xxxx,True,False
# average,average,NOUN,NN,nsubj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Covid,covid,ADJ,JJ,amod,Xxxxx,True,False
# cases,case,NOUN,NNS,pobj,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# NZ,NZ,PROPN,NNP,pobj,XX,True,False
# was,be,AUX,VBD,ccomp,xxx,True,True
# now,now,ADV,RB,advmod,xxx,True,True
# 15,15,NUM,CD,attr,dd,False,False,2024-04-15
# ,,,,PUNCT,,,punct,,,False,False
# compared,compare,VERB,VBN,prep,xxxx,True,False
# with,with,ADP,IN,prep,xxxx,True,True
# 17,17,NUM,CD,nummod,dd,False,False,2024-04-17
# last,last,ADJ,JJ,amod,xxxx,True,True,last
# week,week,NOUN,NN,pobj,xxxx,True,False,week
# and,and,CCONJ,CC,cc,xxx,True,True
# 19,19,NUM,CD,conj,dd,False,False,2024-04-19
# the,the,DET,DT,det,xxx,True,True,the
# week,week,NOUN,NN,npadvmod,xxxx,True,False,week
# before,before,ADV,RB,advmod,xxxx,True,True,before
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# are,be,AUX,VBP,aux,xxx,True,True
# making,make,VERB,VBG,ROOT,xxxx,True,False
# progress,progress,NOUN,NN,dobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# Many,many,ADJ,JJ,nsubjpass,Xxxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# our,our,PRON,PRP$,poss,xxx,True,True
# clusters,cluster,NOUN,NNS,pobj,xxxx,True,False
# are,be,AUX,VBP,auxpass,xxx,True,True
# now,now,ADV,RB,advmod,xxx,True,True
# considered,consider,VERB,VBN,ccomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# contained,contain,VERB,VBN,xcomp,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# or,or,CCONJ,CC,cc,xx,True,True
# clusters,cluster,NOUN,NNS,nsubj,xxxx,True,False
# are,be,AUX,VBP,conj,xxx,True,True
# dormant,dormant,ADJ,JJ,acomp,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# ",",PUNCT,'',punct,",False,False
# Bloomfield,Bloomfield,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# was,be,AUX,VBD,ccomp,xxx,True,True
# clear,clear,ADJ,JJ,acomp,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# virus,virus,NOUN,NN,nsubj,xxxx,True,False
# was,be,AUX,VBD,aux,xxx,True,True
# now,now,ADV,RB,advmod,xxx,True,True
# continuing,continue,VERB,VBG,ccomp,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# transmit,transmit,VERB,VB,xcomp,xxxx,True,False
# among,among,ADP,IN,prep,xxxx,True,True
# specific,specific,ADJ,JJ,amod,xxxx,True,False
# groups,group,NOUN,NNS,pobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# there,there,ADV,RB,expl,xxxx,True,True
# needed,need,VERB,VBD,conj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# be,be,AUX,VB,xcomp,xx,True,True
# a,a,DET,DT,det,x,True,True
# much,much,ADV,RB,advmod,xxxx,True,True
# more,more,ADV,RBR,advmod,xxxx,True,True
# targeted,targeted,ADJ,JJ,amod,xxxx,True,False
# approach,approach,NOUN,NN,attr,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# stamping,stamp,VERB,VBG,pcomp,xxxx,True,False
# out,out,ADP,RP,prt,xxx,True,True
# the,the,DET,DT,det,xxx,True,True
# virus,virus,NOUN,NN,dobj,xxxx,True,False
# quickly,quickly,ADV,RB,advmod,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# are,be,AUX,VBP,ROOT,xxx,True,True
# on,on,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# knife,knife,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# edge,edge,NOUN,NN,pobj,xxxx,True,False
# at,at,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True
# moment,moment,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
# ",",PUNCT,``,punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Without,without,ADP,IN,prep,Xxxxx,True,True
# a,a,DET,DT,det,x,True,True
# targeted,target,VERB,VBN,amod,xxxx,True,False
# approach,approach,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# Baker,Baker,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,parataxis,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# Auckland,Auckland,PROPN,NNP,nsubj,Xxxxx,True,False
# could,could,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,aux,xx,True,True
# hovering,hover,VERB,VBG,ROOT,xxxx,True,False
# between,between,ADP,IN,prep,xxxx,True,True
# level,level,NOUN,NN,pobj,xxxx,True,False
# 2,2,NUM,CD,nummod,d,False,False
# and,and,CCONJ,CC,cc,xxx,True,True
# level,level,NOUN,NN,conj,xxxx,True,False
# 3,3,NUM,CD,nummod,d,False,False
# for,for,ADP,IN,prep,xxx,True,True
# some,some,DET,DT,det,xxxx,True,True
# time,time,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Act,Act,PROPN,NNP,compound,Xxx,True,False
# leader,leader,NOUN,NN,compound,xxxx,True,False
# David,David,PROPN,NNP,compound,Xxxxx,True,False
# Seymour,Seymour,PROPN,NNP,nsubj,Xxxxx,True,False
# criticised,criticise,VERB,VBD,ROOT,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# length,length,NOUN,NN,dobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# time,time,NOUN,NN,pobj,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# has,have,AUX,VBZ,aux,xxx,True,True
# taken,take,VERB,VBN,relcl,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# trial,trial,NOUN,NN,compound,xxxx,True,False
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# saying,say,VERB,VBG,advcl,xxxx,True,False
# nothing,nothing,PRON,NN,nsubj,xxxx,True,True
# has,have,AUX,VBZ,aux,xxx,True,True
# changed,change,VERB,VBN,ccomp,xxxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# the,the,DET,DT,det,xxx,True,True,the
# past,past,ADJ,JJ,amod,xxxx,True,False,past
# six,six,NUM,CD,nummod,xxx,True,True,six
# months,month,NOUN,NNS,pobj,xxxx,True,False,months
# and,and,CCONJ,CC,cc,xxx,True,True
# the,the,DET,DT,det,xxx,True,True
# Government,Government,PROPN,NNP,nsubjpass,Xxxxx,True,False
# was,be,AUX,VBD,aux,xxx,True,True
# being,be,AUX,VBG,auxpass,xxxx,True,True
# driven,drive,VERB,VBN,conj,xxxx,True,False
# by,by,ADP,IN,agent,xx,True,True
# public,public,ADJ,JJ,amod,xxxx,True,False
# opinion,opinion,NOUN,NN,compound,xxxx,True,False
# research,research,NOUN,NN,pobj,xxxx,True,False
# instead,instead,ADV,RB,advmod,xxxx,True,False
# of,of,ADP,IN,cc,xx,True,True
# science,science,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# We,we,PRON,PRP,nsubj,Xx,True,True
# should,should,AUX,MD,aux,xxxx,True,True
# be,be,AUX,VB,ROOT,xx,True,True
# up,up,ADV,RB,advmod,xx,True,True
# to,to,ADP,IN,prep,xx,True,True
# thousands,thousand,NOUN,NNS,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False
# per,per,ADP,IN,prep,xxx,True,True
# week,week,NOUN,NN,pobj,xxxx,True,False
# on,on,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolation,isolation,NOUN,NN,compound,xxxx,True,False
# scheme,scheme,NOUN,NN,pobj,xxxx,True,False
# like,like,ADP,IN,prep,xxxx,True,False
# this,this,PRON,DT,pobj,xxxx,True,True
# .,.,PUNCT,.,punct,.,False,False
# The,the,DET,DT,det,Xxx,True,True
# whole,whole,NOUN,NN,nsubj,xxxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# Auckland,Auckland,PROPN,NNP,pobj,Xxxxx,True,False
# has,have,AUX,VBZ,aux,xxx,True,True
# been,be,AUX,VBN,ROOT,xxxx,True,True
# self,self,NOUN,NN,npadvmod,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolating,isolate,VERB,VBG,acomp,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# the,the,DET,DT,det,xxx,True,True,the
# past,past,ADJ,JJ,amod,xxxx,True,False,past
# seven,seven,NUM,CD,nummod,xxxx,True,False,seven
# weeks,week,NOUN,NNS,pobj,xxxx,True,False,weeks
# .,.,PUNCT,.,punct,.,False,False
# Announcing,announce,VERB,VBG,csubj,Xxxxx,True,False
# 150,150,NUM,CD,nummod,ddd,False,False
# travellers,traveller,NOUN,NNS,dobj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# self,self,NOUN,NN,compound,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# isolate,isolate,NOUN,NN,nsubj,xxxx,True,False
# after,after,ADP,IN,prep,xxxx,True,True
# travelling,travel,VERB,VBG,pcomp,xxxx,True,False
# is,be,AUX,VBZ,ROOT,xx,True,True
# hardly,hardly,ADV,RB,advmod,xxxx,True,False
# news,news,NOUN,NN,acomp,xxxx,True,False
# to,to,ADP,IN,prep,xx,True,True
# them,they,PRON,PRP,pobj,xxxx,True,True
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# ",",PUNCT,``,punct,",False,False
# A,a,DET,DT,det,X,True,True
# business,business,NOUN,NN,compound,xxxx,True,False
# travel,travel,NOUN,NN,compound,xxxx,True,False
# network,network,NOUN,NN,nsubjpass,xxxx,True,False
# was,be,AUX,VBD,auxpass,xxx,True,True
# first,first,ADV,RB,advmod,xxxx,True,True
# proposed,propose,VERB,VBN,ROOT,xxxx,True,False
# by,by,ADP,IN,agent,xx,True,True
# Act,Act,PROPN,NNP,pobj,Xxx,True,False
# in,in,ADP,IN,prep,xx,True,True
# March,March,PROPN,NNP,pobj,Xxxxx,True,False,2024-03-01 TO 2024-03-31
# as,as,ADP,IN,prep,xx,True,True
# part,part,NOUN,NN,pobj,xxxx,True,True
# of,of,ADP,IN,prep,xx,True,True
# our,our,PRON,PRP$,poss,xxx,True,True
# Covid,Covid,PROPN,NNP,nmod,Xxxxx,True,False
# 2.0,2.0,NUM,CD,nummod,d.d,False,False
# paper,paper,NOUN,NN,pobj,xxxx,True,False
# when,when,SCONJ,WRB,advmod,xxxx,True,True
# we,we,PRON,PRP,nsubj,xx,True,True
# said,say,VERB,VBD,advcl,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# ',',PUNCT,``,punct,',False,False
# The,the,DET,DT,det,Xxx,True,True
# Business,Business,PROPN,NNP,compound,Xxxxx,True,False
# Travel,Travel,PROPN,NNP,compound,Xxxxx,True,False
# Network,Network,PROPN,NNP,nsubj,Xxxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# establish,establish,VERB,VB,ccomp,xxxx,True,False
# special,special,ADJ,JJ,amod,xxxx,True,False
# requirements,requirement,NOUN,NNS,dobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# business,business,NOUN,NN,compound,xxxx,True,False
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# come,come,VERB,VB,advcl,xxxx,True,False
# here,here,ADV,RB,advmod,xxxx,True,True
# while,while,SCONJ,IN,mark,xxxx,True,True
# safely,safely,ADV,RB,advmod,xxxx,True,False
# managing,manage,VERB,VBG,advcl,xxxx,True,False
# the,the,DET,DT,det,xxx,True,True
# risk,risk,NOUN,NN,dobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# Covid-19,Covid-19,PROPN,NNP,pobj,Xxxxx-dd,False,False
# .,.,PUNCT,.,punct,.,False,False
# ',',PUNCT,'',punct,',False,False
# ",",PUNCT,``,punct,",False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# He,he,PRON,PRP,nsubj,Xx,True,True
# said,say,VERB,VBD,ROOT,xxxx,True,False
# Act,Act,PROPN,NNP,poss,Xxx,True,False
# 's,'s,PART,POS,case,'x,False,True
# policy,policy,NOUN,NN,nsubj,xxxx,True,False
# also,also,ADV,RB,advmod,xxxx,True,True
# had,have,VERB,VBD,ccomp,xxx,True,True
# a,a,DET,DT,det,x,True,True
# traffic,traffic,NOUN,NN,compound,xxxx,True,False
# light,light,NOUN,NN,compound,xxxx,True,False
# system,system,NOUN,NN,dobj,xxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# special,special,ADJ,JJ,amod,xxxx,True,False
# testing,testing,NOUN,NN,compound,xxxx,True,False
# requirements,requirement,NOUN,NNS,conj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Meanwhile,meanwhile,ADV,RB,advmod,Xxxxx,True,True
# ,,,,PUNCT,,,punct,,,False,False
# the,the,DET,DT,det,xxx,True,True
# plan,plan,NOUN,NN,nsubj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# reopen,reopen,VERB,VB,acl,xxxx,True,False
# quarantine,quarantine,NOUN,NN,npadvmod,xxxx,True,False
# -,-,PUNCT,HYPH,punct,-,False,False
# free,free,ADJ,JJ,amod,xxxx,True,False
# travel,travel,NOUN,NN,dobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# RSE,RSE,PROPN,NNP,compound,XXX,True,False
# workers,worker,NOUN,NNS,pobj,xxxx,True,False
# from,from,ADP,IN,prep,xxxx,True,True
# the,the,DET,DT,det,xxx,True,True
# Pacific,Pacific,PROPN,NNP,pobj,Xxxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# start,start,VERB,VB,ccomp,xxxx,True,False
# again,again,ADV,RB,advmod,xxxx,True,True
# with,with,ADP,IN,prep,xxxx,True,True
# Vanuatu,Vanuatu,PROPN,NNP,pobj,Xxxxx,True,False
# from,from,ADP,IN,prep,xxxx,True,True
# early,early,ADJ,JJ,amod,xxxx,True,False,early
# October,October,PROPN,NNP,pobj,Xxxxx,True,False,2024-10-01 TO 2024-10-31
# ,,,,PUNCT,,,punct,,,False,False
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# All,all,DET,PDT,predet,Xxx,True,True
# those,those,PRON,DT,nsubj,xxxx,True,True
# taking,take,VERB,VBG,acl,xxxx,True,False
# part,part,NOUN,NN,dobj,xxxx,True,True
# from,from,ADP,IN,prep,xxxx,True,True
# Vanuatu,Vanuatu,PROPN,NNP,pobj,Xxxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# Samoa,Samoa,PROPN,NNP,conj,Xxxxx,True,False
# and,and,CCONJ,CC,cc,xxx,True,True
# Tonga,Tonga,PROPN,NNP,conj,Xxxxx,True,False
# would,would,AUX,MD,aux,xxxx,True,True
# need,need,VERB,VB,ROOT,xxxx,True,False
# at,at,ADP,IN,advmod,xx,True,True
# least,least,ADV,RBS,advmod,xxxx,True,True
# one,one,NUM,CD,nummod,xxx,True,True
# vaccine,vaccine,NOUN,NN,nsubj,xxxx,True,False
# dose,dose,NOUN,NN,ccomp,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# Ardern,Ardern,PROPN,NNP,nsubj,Xxxxx,True,False
# said,say,VERB,VBD,ROOT,xxxx,True,False
# it,it,PRON,PRP,nsubj,xx,True,True
# allowed,allow,VERB,VBD,ccomp,xxxx,True,False
# a,a,DET,DT,det,x,True,True
# trial,trial,NOUN,NN,dobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# a,a,DET,DT,det,x,True,True
# ",",PUNCT,``,punct,",False,False
# pseudo,pseudo,NOUN,NN,nmod,xxxx,True,False
# ",",PUNCT,'',punct,",False,False
# form,form,NOUN,NN,pobj,xxxx,True,False
# of,of,ADP,IN,prep,xx,True,True
# shortened,shorten,VERB,VBN,amod,xxxx,True,False
# isolation,isolation,NOUN,NN,pobj,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# some,some,DET,DT,det,xxxx,True,True
# travellers,traveller,NOUN,NNS,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
#
# ,
# ,SPACE,_SP,dep,
# ,False,False
# RSE,RSE,PROPN,NNP,compound,XXX,True,False
# workers,worker,NOUN,NNS,nsubj,xxxx,True,False
# will,will,AUX,MD,aux,xxxx,True,True
# also,also,ADV,RB,advmod,xxxx,True,True
# have,have,VERB,VB,ROOT,xxxx,True,True
# to,to,PART,TO,aux,xx,True,True
# isolate,isolate,VERB,VB,xcomp,xxxx,True,False
# for,for,ADP,IN,prep,xxx,True,True
# seven,seven,NUM,CD,nummod,xxxx,True,False,seven
# days,day,NOUN,NNS,pobj,xxxx,True,False,days
# on,on,ADP,IN,prep,xx,True,True
# arrival,arrival,NOUN,NN,pobj,xxxx,True,False
# ,,,,PUNCT,,,punct,,,False,False
# but,but,CCONJ,CC,cc,xxx,True,True
# this,this,PRON,DT,nsubj,xxxx,True,True
# does,do,AUX,VBZ,aux,xxxx,True,True
# not,not,PART,RB,neg,xxx,True,True
# need,need,VERB,VB,conj,xxxx,True,False
# to,to,PART,TO,aux,xx,True,True
# be,be,AUX,VB,auxpass,xx,True,True
# done,do,VERB,VBN,xcomp,xxxx,True,True
# at,at,ADP,IN,prep,xx,True,True
# an,an,DET,DT,det,xx,True,True
# MIQ,MIQ,PROPN,NNP,compound,XXX,True,False
# facility,facility,NOUN,NN,pobj,xxxx,True,False
# .,.,PUNCT,.,punct,.,False,False
